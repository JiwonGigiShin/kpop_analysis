# %% [markdown]
# # Data Prep

# %%
import pandas as pd

# %%
#whole dataframe
gg_df = pd.read_csv('gg_final_dataframe.csv', index_col = 'artist_id')

# %%
#Select an artist
twice_df = gg_df[gg_df['artist_x']=='TWICE (트와이스)'][['artist_x', 'song_name', 'year', 'Lyric']]
twice_df
# Out:
#                artist_x             song_name  year  \
# artist_id
# 80249916   TWICE (트와이스)        Talk that Talk  2022
# 80249916   TWICE (트와이스)       Queen of Hearts  2022
# 80249916   TWICE (트와이스)                Basics  2022
# 80249916   TWICE (트와이스)                 Brave  2022
# 80249916   TWICE (트와이스)               Trouble  2022
# 80249916   TWICE (트와이스)     When We Were Kids  2022
# 80249916   TWICE (트와이스)                  Gone  2022
# 80249916   TWICE (트와이스)                    TT  2016
# 80249916   TWICE (트와이스)           JELLY JELLY  2016
# 80249916   TWICE (트와이스)      ONE IN A MILLION  2016
# 80249916   TWICE (트와이스)             PIT-A-PAT  2016
# 80249916   TWICE (트와이스)             NEXT PAGE  2016
# 80249916   TWICE (트와이스)              CHEER UP  2016
# 80249916   TWICE (트와이스)                소중한 사랑  2016
# 80249916   TWICE (트와이스)             Touchdown  2016
# 80249916   TWICE (트와이스)  Dance The Night Away  2018
# 80249916   TWICE (트와이스)               CHILLAX  2018
# 80249916   TWICE (트와이스)           KNOCK KNOCK  2017
# 80249916   TWICE (트와이스)               1 TO 10  2017
# 80249916   TWICE (트와이스)                   녹아요  2017
# 80249916   TWICE (트와이스)              PONYTAIL  2017
# 80249916   TWICE (트와이스)             OOH-AHH하게  2015
# 80249916   TWICE (트와이스)                 다시 해줘  2015
# 80249916   TWICE (트와이스)                  미쳤나봐  2015
# 80249916   TWICE (트와이스)                 LIKEY  2017
# 80249916   TWICE (트와이스)                   거북이  2017
# 80249916   TWICE (트와이스)             MISSING U  2017
# 80249916   TWICE (트와이스)          Alcohol-Free  2021
# 80249916   TWICE (트와이스)            YES or YES  2018
# 80249916   TWICE (트와이스)     BDZ (Korean Ver.)  2018
# 80249916   TWICE (트와이스)       SAY YOU LOVE ME  2018
# 80249916   TWICE (트와이스)         What is Love?  2018
# 80249916   TWICE (트와이스)          SWEET TALKER  2018
# 80249916   TWICE (트와이스)                   HO!  2018
# 80249916   TWICE (트와이스)          Heart Shaker  2017
# 80249916   TWICE (트와이스)         Merry & Happy  2017
# 80249916   TWICE (트와이스)                SIGNAL  2017
# 80249916   TWICE (트와이스)                ONLY 너  2017
# 80249916   TWICE (트와이스)                 FANCY  2019
# 80249916   TWICE (트와이스)          Feel Special  2019
# 80249916   TWICE (트와이스)       I CAN’T STOP ME  2020
# 80249916   TWICE (트와이스)        HELL IN HEAVEN  2020
# 80249916   TWICE (트와이스)            UP NO MORE  2020
# 80249916   TWICE (트와이스)         SAY SOMETHING  2020
# 80249916   TWICE (트와이스)             SCIENTIST  2021
# 80249916   TWICE (트와이스)           MORE & MORE  2020
# 80249916   TWICE (트와이스)             The Feels  2022
# 80249916   TWICE (트와이스)             The Feels  2021
# 80249916   TWICE (트와이스)            올해 제일 잘한 일  2018
# 80249916   TWICE (트와이스)            CRY FOR ME  2020
# 80249916   TWICE (트와이스)            누구보다 널 사랑해  2021
#
#                                                        Lyric
# artist_id
# 80249916   [날 보는 Eyes 씩 웃는 Lips\n맘에 들지 I like it (Oh yeah...
# 80249916   [Watch me run, watch me run away\nGot no ties ...
# 80249916   [First time 눈이 마주친 순간\n어질어질한 이 공간\n꿈속인지 헷갈려 숨이...
# 80249916   [Brave brave brave for ya\nBrave brave brave f...
# 80249916   [돌이킬 수 없어 이미 우린\n아슬한 줄다리기 속에 Yeah \n우린 서로를 끌어당...
# 80249916   [We were kids 호기심 가득하던 때\n조금 서툴렀었지\nYou and me...
# 80249916   [순간의 흔들림으로 쉽게 질려 떠나버리고\nI wonder what else\n입술...
# 80249916   [이러지도 못하는데 저러지도 못하네\n그저 바라보며 ba-ba-ba-baby\n매일...
# 80249916   [우 jelly jelly 우 jelly jelly \n우 jelly jelly o...
# 80249916   [You gotta know \nthat you’re one in a million...
# 80249916   [내 맘이 하루 종일 pinky pinky 해 \n내 볼이 사과처럼 부끄부끄 해 w...
# 80249916   [어제 몇 번이고\n연습했는데\n지금 내 표정 봐\n말도 못하게\n두근두근 대 나 ...
# 80249916   [매일 울리는 벨벨벨 \n이젠 나를 배려 해줘 \n배터리 낭비하긴 싫어 \n자꾸만 ...
# 80249916   [I’m so sorry Please come back\n그대 아직도 그대론 가요 ...
# 80249916   [시간아 10 9 8 달려봐 10 9 8 7 6 \n내게로 5 4 3 빠져봐 5 4...
# 80249916   [나나나나나나나\n나나나나나나나\nYou and me in the moonlight...
# 80249916   [바빠 오늘은 피곤해\n입에 붙어버린 그 말\n딱 일주일만 쉬고 싶은데\n어디론가 ...
# 80249916   [열두시가 되면 닫혀요\n조금만 서둘러 줄래요\nKnock knock knock k...
# 80249916   [Baby, I know you know,\nI know you know it, T...
# 80249916   [함께한 시간들이 매일 부족해\n오늘도 아쉬워 내 맘 숨겼었죠\n조금 더 있어줘요 ...
# 80249916   [축 쳐진 어깨 자신 없는 표정\n시작도 전에 너무 많은 걱정\nSomebody s...
# 80249916   [모두 나를 가지고\n매일 가만 안 두죠\n내가 너무 예쁘죠\n나 때문에 다 힘들죠...
# 80249916   [You ready girls\nDJ Drop it Wow!\n\n지금 혹시 내게 ...
# 80249916   [아이코 맙소사\n왜 이러니 왜 또 나\n너만 보이면\n살랑살랑 네게 다가가\n\n...
# 80249916   [설렌다 me likey me likey likey likey\nMe likey l...
# 80249916   [처음엔 아무 느낌 없었는데\n매일 티격 대면서 우리 싫지는 않았나 봐\n가끔 빤히...
# 80249916   [그땐 가지마 가지마\n난생처음 나답지 않게\n울고불고 매달렸어 oh\n이젠 하룻밤...
# 80249916   [너와 있을 땐 내게\n신기한 변화가 있는데\n자꾸 미소 짓게 돼\n아무 일도 없는...
# 80249916   [Hey boy\nLook I'm gonna make this simple for ...
# 80249916   [Like a bulldozer\nLike a tank\nLike a soldier...
# 80249916   [우리 사이를 좀 바꾸고 싶어서\n매일 고민뿐 고민뿐\n나의 머릿속 타투\n지워지지...
# 80249916   [매일같이 영화 속에서나\n책 속에서나 드라마 속에서\n사랑을 느껴\nUm 사랑을 ...
# 80249916   [Ah ooh ah sweet talker\nAh ooh ah\n아주 달콤한 말로 ...
# 80249916   [매일 걸었던 그 길이\n분명 이 길이 맞는데\n오늘은 다른 것 같아\n며칠 꿀꿀한...
# 80249916   [Yeah yeah yeah yeah yeah\nCome and be my love...
# 80249916   [매년 12월 달력을 넘길 때마다\n시작되는 그 알 수 없는 허전함은\n모른 척을 ...
# 80249916   [Trying to let you know\nSign을 보내 signal 보내\nI...
# 80249916   [Only oh only only 너\nOnly oh only only 너\nOnl...
# 80249916   [지금 하늘 구름 색은 Tropical yeah\n저 태양 빨간빛 네 두 볼 같아\...
# 80249916   [그런 날이 있어\n갑자기 혼자인 것만 같은 날\n어딜 가도 내 자리가 아닌 것만 ...
# 80249916   [알람이 울려대 Ring ring a ling\n서로의 눈길이 닿을 때마다\n알면서...
# 80249916   [네 눈은 가시 박힌 Diamond 같애\n천사와 악마가 왔다 갔다 해\n천국과 지...
# 80249916   [Uh yeah yeah\n어둠이 짙게 깔린 이 밤 홀로\n아직도 환한 내 하룰 끄...
# 80249916   [매일이 별다를 것 없던 기억들이\n변해가는 것 같아\nWhere are we\n우...
# 80249916   [왜 자꾸 날 연구해\n아인슈타인도 아니고\n왜 그렇게 각을 재\nSin cos도 ...
# 80249916   [I know I want it\n입에 바른 소린 이제 그만할게\nCause I d...
# 80249916   [Boy I boy I boy I know\nI know you get the fe...
# 80249916   [Boy I boy I boy I know\nI know you get the fe...
# 80249916   [The best thing I ever did\nDecember 1년의 끝을 너와...
# 80249916   [I know 고쳐 쓸 가치도 없단 걸\n하지만 그녀와 달리 난 널\n쉽게 놔줄 맘...
# 80249916   [이 세상 누구보다 널 사랑해\n너의 작은 세상을\n바이올렛 향기 같은\n너의 미소...

# %% [markdown]
# # text basic cleaning

# %%
manual_sw = ['im', 'youre', "n't", '내', '나를', '나의', '너의', '난', '날', '내가', '너','나', '그', '니', '걸', '거야', '수', '다', '더',
'널', '네', '니가', '네가', '널', '너를', '넌', '내게', '이', 'l', 'u', '-',
'na', 'ah', 'e','m', 'uh', 'eh', 's', 'la', 'a', 'o', 'ta', 't', 'oh', 'du', 'yeah', '’', 'amp', 'comp',
'tu', 'ye', 'it', 'i', 'but', '너무', 'so', 'in', '또', 'roob', '왔니', '조금', '꼭', '이렇게',
'bo', 'peep', 'the','lolli', '정말', 'for', 'lollipop', '이제', 'on', 'muzik', 'lets', 'about', 
'처', 'amoled', '좀', '두', '닷닷닷닷닷', '어쩌다', '4', 'is', 'and', 'to', 'you', 'me','huh', 'now', 'ooop',
'just', 're', 'jumpin', 'dori', 'let', 'one', '아', 'ma', 'take', 'its', 'woo', 'this', 'that',
'whoo', 'get', 'are', 'dovey', 'hey', '어머어머', 'hush', '오', '나는', '너는', '슈가프리', '자꾸', '위', '아래', '것', '있어', '같아', '돼', 'ya', 'tickle', 'ha',
'way', '싶어', '같은', '오늘', '딱', '않아', '마', 'poppy','같아', 'day', 'be', 'rollin', '게', 'ba', 'hoo', 'ey', 'pa', 'ooh', 'swan', 'woo', 'ill', 'da', 'zu',
'zim', 'dam', 'dda', 'got', 'umpah','안', '건', '할','것도', 'at', 'yah', 'all', 'with']

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
# !pip install cleantext

# %%
import re
import string
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

from cleantext import clean
import string
import re


def clean_text(text):
    #changing to lowercase
    text = text.lower()
    text = text.replace('\r','')
    
    # removing #´s 
    text = re.sub(r'#[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    
    #indentation -> space
    text = re.sub(r'\n', ' ', text)
    
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '') 
    
    text = text.strip()
    
    #tokenization
    tokens = word_tokenize(text)   
    filtered_words = [w for w in tokens if w not in manual_sw]
    final = " ".join(cat for cat in filtered_words)
    
    return final

def kor_to_eng(text):

    text = text.replace("사랑", "love")
    text = text.replace("좋아", "like") # like has multiple meanings, so needs to n-gram as well
    text = text.replace("키스", "kiss")
    text = text.replace("입맞", "kiss")
    text = text.replace("뽀뽀", "kiss")
    text = text.replace("터치", 'touch')
    text = text.replace("안아", 'hug')
    text = text.replace("원해", "want")
    text = text.replace("원하", "want")
    text = text.replace("밤", "night")
    
    #gender-specific
    text = text.replace("남자", "man")
    text = text.replace("소년", 'boy')
    text = text.replace("오빠", "oppa")
    text = text.replace("그의", 'him')
    text = text.replace("그에게", 'him')
    text = text.replace("그와", 'him')
    text = text.replace("그를", 'him')
    text = text.replace("그가", 'him')
    text = text.replace("그는", 'him')
    text = text.replace("놈", 'guy')
    
    text = text.replace("소녀", "so-nyeo") #young girl (少女)
    text = text.replace("여자", "woman")
    text = text.replace("그녀", 'her')
    
# want & girl should be dealt with n-grams because the meaning is completely different 
#between English and Korean
    
    #돈 (money)
      
    return text


def by_year(df):
    df['cleaned_lyrics'] = df.Lyric.apply(clean_text)
    df['final_lyrics'] = df.cleaned_lyrics.apply(kor_to_eng)
    df.drop(columns = ['Lyric', 'cleaned_lyrics'], inplace = True)# bp_df
    df = df.groupby(['year']).sum()[['final_lyrics']]
    return df

# %% [markdown]
# # By year

# %%
nltk.download('punkt')

# %%
# replace blackpink with other artists
by_year = by_year(twice_df)
by_year
# Out:
#                                            final_lyrics
# year
# 2015  모두 가지고 매일 가만 두죠 예쁘죠 때문에 힘들죠 어딜 걷고 있어도 빨간 바닥인 거...
# 2016  이러지도 못하는데 저러지도 못하네 그저 바라보며 bababababy 매일 상상만 해...
# 2017  열두시가 되면 닫혀요 조금만 서둘러 줄래요 knock knock knock knoc...
# 2018  나나나나나나나 나나나나나나나 moonlight 별 꽃 축제 열린 night 파도 소...
# 2019  지금 하늘 구름 색은 tropical 저 태양 빨간빛 볼 tell only baby...
# 2020  알람이 울려대 ring ring ling 서로의 눈길이 닿을 때마다 알면서 빙빙 도...
# 2021  너와 있을 땐 신기한 변화가 있는데 미소 짓게 아무 일도 없는데 마법에 걸려 nig...
# 2022  보는 eyes 씩 웃는 lips 맘에 들지 like z 꽤 달콤해 thats rig...

# %%
def words_by_year(year):
    df_by_year = by_year.loc[year, :]
    df_2 = " ".join(cat for cat in df_by_year)
    return df_2

# %%
df_2015 = words_by_year(2015)
df_2016 = words_by_year(2016)
df_2017 = words_by_year(2017)
df_2018 = words_by_year(2018)
df_2019 = words_by_year(2019)
df_2020 = words_by_year(2020)
df_2021 = words_by_year(2021)
df_2022 = words_by_year(2022)

# %%
# replace blackpink with other artists
twice_total = " ".join(cat for cat in twice_df.final_lyrics)
twice_total
# Out:
# '보는 eyes 씩 웃는 lips 맘에 들지 like z 꽤 달콤해 thats right wan skip skip 결정적인 thing thing 본론을 want 빙빙 돌린 서론 따위 말고 mean word 보여줘 보여줘 알려줘 알려줘 지금 need some hints 채우고 너란 crosswords beep beep beep beep beep time up 이미 알 같지만 목소리로 바로 듣고 싶은데 baby 답은 뻔하잖아 yes or yes 밀거나 당기는 괜한 시간 낭비는 싫으니 과감하게 say want 1 10 시작해볼까 right tell what want tell what need z 말해봐 시작은 해 talk talk 한 마디 talk talk love 들려줘 turn up 눈 look look look 위아래로 roll roll roll 읽었잖아 뭐 피차 눈빛 사이 오고 가는 말 차근차근 1 2 3 1 2 3 친절하게 abc like abc dont stop replay replay thats my only request baby 안고 달콤하게 달콤하게 tell tell 때로는 뻔한 말이 좋다는 알잖니 favorite part 지금이야 want more were almost there 시작해볼까 right tell what want tell what need z 말해봐 시작은 해 talk talk 한 마디 talk talk love 들려줘 단순한 words love한다는 말 그게 다야 꾸밈없이 듣길 want지 미루지 너에게 다가가 심플하게 말할게 love tell what want tell what need z 좋지만 말이 제일 좋은데 talk talk 한 마디 talk talk love sounds good 빠져들어 푹 tell what want tell what need 한 번 해줘 그래 방금 말 talk talk 한 마디 talk talk love 들려줘 turn up watch run watch run away no ties left yesterday know who was put here no intention slow down burn my past fireplace from ashes rise again looking future bright gon make mine gon make mine show how do out here making these moves aint here play aint ready watch go watch go rule world know never doubted baby imma go run whole universe baby was born rule queen queen because of queen of hearts see clear as dreaming bout would rule world surrounded by my girls we shining bright like diamonds pearls made like movement bow up stage my friends know how do can do too follow making shine today can do do everyday show how do out here making these moves aint here play aint ready watch go watch go rule world know never doubted baby imma go run whole universe baby was born rule queen queen because of queen of hearts screaming out my name see stage lights feel lucky have cause know deep down was meant something bigger greater know seeing what see see what see everything need know gon walk walk talk talk there can only aint ready watch go watch go rule world know never doubted baby imma go run whole universe baby was born rule queen queen because of queen of hearts thank memories ones who made thank memories queen of hearts first time 눈이 마주친 순간 어질어질한 공간 꿈속인지 헷갈려 숨이 차올라 가까이 다가와 천천히 can make feel like diamond what 다른 애들과는 달라 aint beggin love 나쁜 아니잖아 이게 나라서 어디로 튈지 몰라 like rainbow bubble gum 그러니 꽉 붙잡아둬 알아 나도 well myself 쉽지 않단 might want some help wan try not tonight imma call my friend up off my makeup imma sleep good tonight ok wan wan wan basics want want want 서두르지 baby 뻔해 뻔해 말해 뭐해 알 텐데 타는 듯 뜨거운 사막 위에 예쁘게 피어난 장미 조심스레 다가올 때 나도 모르게 찔러버릴 텐데 긴장이 필요한 순간이야 정신을 놓지 지금이야 궁금하잖아 전화기를 들어 질문을 던져 대답해줄게 알아 나도 well myself 쉽지 않단 might want some help wan try not tonight imma call my friend up off my makeup imma sleep good tonight ok wan wan wan basics want want want 서두르지 baby 뻔해 뻔해 말해 뭐해 알 텐데 wan wan wan basics slow down speed up like spaceship baby later 남겨 줄게 my location 부족하다고 느끼겠지만 기본에 충실한 태도일 뿐이야 우리 둘 사이 팽팽한 긴장감 놓지 않는 좋단 알아 know feels like paying price 모든 것을 더는 바라지마 back back wan wan wan basics want want want 서두르지 baby 뻔해 뻔해 말해 뭐해 알 텐데 wan wan wan basics slow down speed up like spaceship baby later 남겨 줄게 my location brave brave brave brave brave brave 유난히 깜깜한 night이 두렵던 세상 felt lonely 여전히 헤매는 사이 커버린 세상이 hard breathe 지금 작은 빛 하나 없이 다시 일으키는 sign 들려온 목소린 다시 뛰게 해 fine 벅찬 숨을 고르고 앞을 봐 제대로 전해온 brave brave brave brave never alone never alone brave brave brave brave 상처는 하나로 차올라 cant live without 나이게 해 brave brave brave 숨 쉬게 해 trust babe 끝없는 미로 같던 길이 돼준 너란 sign 커지는 목소린 다시 뛰게 해 fine 벅찬 숨을 고르고 앞을 봐 제대로 이젠 네게 전해줄 brave brave brave brave never alone never alone brave brave brave brave 상처는 하나로 차올라 cant live without 나이게 해 brave brave brave 숨 쉬게 해 trust babe 깊은 상처들에 아물지 않던 맘에 내리던 rain 어느새 멎게 해 유일한 believer 멀리 달리게 만든 dreamer can hear calling only brave never alone never alone brave brave brave brave 상처는 하나로 차올라 cant live without 나이게 해 brave brave brave 숨 쉬게 해 trust babe 돌이킬 없어 이미 우린 아슬한 줄다리기 속에 우린 서로를 끌어당겨 baby no no were trouble go 처음 본 느 ...

# %% [markdown]
# # wordcloud

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2.tar.gz (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.8/220.8 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.6.1 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from wordcloud) (1.23.4)
# Requirement already satisfied: pillow in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from wordcloud) (9.1.1)
# Requirement already satisfied: matplotlib in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: packaging>=20.0 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py) ... done
#   Created wheel for wordcloud: filename=wordcloud-1.8.2.2-cp310-cp310-macosx_13_0_arm64.whl size=154655 sha256=3eaecfd7498596d27e45d4e87fa4584c86e6e25c2aff65e5358590b1a0da0f30
#   Stored in directory: /Users/hayeonkim/Library/Caches/pip/wheels/9b/fe/91/c3a2166a21f3f9515fa4660b498a9f69223847a8323f58556b
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %%
def word_cloud_year(df):
    word_cloud = WordCloud(font_path='Binggrae', width = 1000, height = 300, 
    colormap='BuPu', max_words=100, collocations = False).generate(df)

    plt.figure(figsize = (10,8))
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## wordcloud by year

# %%
word_cloud_year(df_2015)

# %%
word_cloud_year(df_2016)

# %%
word_cloud_year(df_2017)

# %%
word_cloud_year(df_2018)

# %%
word_cloud_year(df_2019)

# %%
word_cloud_year(df_2020)

# %%
word_cloud_year(df_2021)

# %%
word_cloud_year(df_2022)

# %% [markdown]
# ## total wordcloud

# %%
word_cloud_year(twice_total)

# %% [markdown]
# # word ranking

# %%
def word_ranking(df_year):

    wordlist = df_year.split()
    wordfreq = [wordlist.count(p) for p in wordlist]
    freqdict = dict(list(zip(wordlist,wordfreq)))

    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    
    df = pd.DataFrame(aux)
    df = df.rename(columns = {0: 'frequency', 1:'keyword'})
    
    return df[:200]

# %%
#replace 'blackpink_total' - > '@@@@@@_total'

keyword_total = word_ranking(twice_total)
keyword_total
# Out:
#      frequency  keyword
# 0          173     know
# 1          131     baby
# 2          122    knock
# 3          107      boy
# 4           97       my
# ..         ...      ...
# 195          9      것처럼
# 196          9        거
# 197          9     when
# 198          9    whats
# 199          9  special
#
# [200 rows x 2 columns]

# %%
word_2015 = word_ranking(df_2015)

# %%
word_2016 = word_ranking(df_2016)

# %%
word_2017 = word_ranking(df_2017)

# %%
word_2018 = word_ranking(df_2018)

# %%
word_2019 = word_ranking(df_2019)

# %%
word_2020 = word_ranking(df_2020)

# %%
word_2021 = word_ranking(df_2021)

# %%
word_2022 = word_ranking(df_2022)

# %% [markdown]
# ### plot

# %%
keyword_25 = keyword_total[:25]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(3, 10))

# # Load the example car crash dataset
# keywords = sns.load_dataset("keyword_total").sort_values("frequency", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="frequency", y="keyword", data=keyword_25, color="pink")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 250), ylabel="",
       xlabel="Twice keywords total")
sns.despine(left=True, bottom=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   func(*args, **kwargs)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   func(*args, **kwargs)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 48400 (\N{HANGUL SYLLABLE BWA}) missing from current font.
#   func(*args, **kwargs)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50780 (\N{HANGUL SYLLABLE WAE}) missing from current font.
#   func(*args, **kwargs)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   func(*args, **kwargs)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48400 (\N{HANGUL SYLLABLE BWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50780 (\N{HANGUL SYLLABLE WAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hayeonkim/.pyenv/versions/3.10.6/envs/kpop_analysis/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## word frequency

# %%
def word_by_years(text, word):
    num_of_word = text.count(word)
    len_of_df = len(text)
    ratio = num_of_word / len_of_df *100
    return round(ratio, 3)

# %%
by_year['love'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "love"))
by_year['kiss'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "kiss"))
by_year['touch'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "touch"))
by_year['feel'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "feel"))
by_year['like'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "like"))
by_year['baby'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "baby"))
by_year['night'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "night"))
by_year['my'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "my"))

by_year['so-nyo'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "nyeo"))
by_year['woman'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "woman"))

by_year['he/him/his'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "him"))
by_year['guy'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "guy"))
by_year['boy'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "boy"))
by_year['man'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "man"))
by_year['oppa'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "oppa"))
by_year['mr'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "mr"))

by_year['want'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "wan"))

by_year['girl'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "girl"))
by_year['girls'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "girls"))
by_year['noona'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "noona"))
by_year['her'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "her"))
by_year['lady'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "lady"))

# %% [markdown]
# ## plot

# %%
keywords_df = by_year.drop(columns=['final_lyrics'])
keywords_df = keywords_df.iloc[:-1]
keywords_df
# Out:
#        love   kiss  touch   feel   like   baby  night     my  so-nyo  woman  \
# year
# 2015  0.241  0.000  0.000  0.048  0.241  0.289  0.000  0.145     0.0  0.096
# 2016  0.255  0.000  0.175  0.000  0.525  0.446  0.000  0.191     0.0  0.080
# 2017  0.225  0.011  0.021  0.000  0.664  0.578  0.107  0.450     0.0  0.000
# 2018  0.381  0.000  0.000  0.014  0.204  0.082  0.245  0.027     0.0  0.000
# 2019  0.669  0.000  0.000  0.790  0.243  0.182  0.061  0.122     0.0  0.000
# 2020  0.145  0.062  0.000  0.041  0.021  0.041  0.372  0.186     0.0  0.000
# 2021  0.746  0.000  0.000  0.639  0.080  0.080  0.133  0.320     0.0  0.000
#
#       ...    boy    man   oppa   mr   want   girl  girls  noona    her   lady
# year  ...
# 2015  ...  0.289  0.096  0.048  0.0  0.337  0.096  0.048    0.0  0.000  0.048
# 2016  ...  0.191  0.175  0.000  0.0  0.048  0.000  0.000    0.0  0.064  0.000
# 2017  ...  0.118  0.000  0.000  0.0  0.171  0.021  0.000    0.0  0.011  0.000
# 2018  ...  0.027  0.000  0.000  0.0  0.572  0.000  0.000    0.0  0.014  0.000
# 2019  ...  0.000  0.000  0.000  0.0  0.182  0.000  0.000    0.0  0.000  0.000
# 2020  ...  0.083  0.000  0.000  0.0  0.868  0.083  0.000    0.0  0.041  0.000
# 2021  ...  0.985  0.000  0.000  0.0  0.399  0.000  0.000    0.0  0.000  0.000
#
# [7 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame

plt.figure(figsize = (30,10))

plt.plot(keywords_df['love'], label = 'love', color = 'pink')
# plt.plot(keywords_df['kiss'], label = 'kiss')
# plt.plot(keywords_df['touch'], label = 'touch')
plt.plot(keywords_df['like'], label = 'like')
# plt.plot(keywords_df['woman'], color='red', label = 'woman')
plt.plot(keywords_df['he/him/his'], linestyle='dashed', label = 'he/him/his')
plt.plot(keywords_df['boy'], linestyle='dashed', label = 'boy')
plt.plot(keywords_df['man'], linestyle='dashed', label = 'man')

plt.plot(keywords_df['girl'], label = 'girl') #mostly related to hetero-normative term
plt.plot(keywords_df['girls'], label = 'girls') #mostly related to women empowerment(girlhood)
# plt.plot(keywords_df['so-nyo'], label = 'sonyo') - not significant
plt.plot(keywords_df['baby'], label = 'baby')
# plt.plot(keywords_df['feel'], label = 'feel')
# plt.plot(keywords_df['her'], label = 'her')
# plt.plot(keywords_df['why'], label = 'why')
plt.plot(keywords_df['want'], label = 'want')
plt.plot(keywords_df['night'], label = 'night', color = 'black')

plt.legend(loc='upper left')
plt.xlabel("Year")
plt.ylabel("Keywords")
plt.show()
