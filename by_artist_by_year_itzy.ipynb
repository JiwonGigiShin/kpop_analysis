# %% [markdown]
# # Data Prep

# %%
import pandas as pd

# %%
#whole dataframe
gg_df = pd.read_csv('gg_final_dataframe.csv', index_col = 'artist_id')

# %%
#Select an artist
itzy_df = gg_df[gg_df['artist_x']=='ITZY (있지)'][['artist_x', 'song_name', 'year', 'Lyric']]
itzy_df
# Out:
#             artist_x                             song_name  year  \
# artist_id
# 80327433   ITZY (있지)                              SNEAKERS  2022
# 80327433   ITZY (있지)                                 RACER  2022
# 80327433   ITZY (있지)                           WHAT I WANT  2022
# 80327433   ITZY (있지)                                DOMINO  2022
# 80327433   ITZY (있지)                             Free Fall  2022
# 80327433   ITZY (있지)                                   365  2022
# 80327433   ITZY (있지)               SNEAKERS (English Ver.)  2022
# 80327433   ITZY (있지)                                  달라달라  2019
# 80327433   ITZY (있지)                              WANT IT?  2019
# 80327433   ITZY (있지)                               WANNABE  2020
# 80327433   ITZY (있지)                       NOBODY LIKE YOU  2020
# 80327433   ITZY (있지)                        THAT’S A NO NO  2020
# 80327433   ITZY (있지)                                 24HRS  2020
# 80327433   ITZY (있지)    TING TING TING with Oliver Heldens  2020
# 80327433   ITZY (있지)                           YOU MAKE ME  2020
# 80327433   ITZY (있지)                                   ICY  2019
# 80327433   ITZY (있지)                           IT’z SUMMER  2019
# 80327433   ITZY (있지)                                CHERRY  2019
# 80327433   ITZY (있지)                  달라달라 (DallasK Remix)  2019
# 80327433   ITZY (있지)                               Not Shy  2020
# 80327433   ITZY (있지)                                  SURF  2020
# 80327433   ITZY (있지)                            Be In Love  2020
# 80327433   ITZY (있지)                     Don’t Give A What  2020
# 80327433   ITZY (있지)                                    iD  2020
# 80327433   ITZY (있지)                                Louder  2020
# 80327433   ITZY (있지)                                  LOCO  2021
# 80327433   ITZY (있지)                               #Twenty  2021
# 80327433   ITZY (있지)                                 SWIPE  2021
# 80327433   ITZY (있지)                            Sooo LUCKY  2021
# 80327433   ITZY (있지)                     Chillin’ Chillin’  2021
# 80327433   ITZY (있지)                               LOVE is  2021
# 80327433   ITZY (있지)                             Gas Me Up  2021
# 80327433   ITZY (있지)                                Mirror  2021
# 80327433   ITZY (있지)                           B[OO]M-BOXX  2021
# 80327433   ITZY (있지)                              Cheshire  2022
# 80327433   ITZY (있지)                         Boys Like You  2022
# 80327433   ITZY (있지)                                 Snowy  2022
# 80327433   ITZY (있지)                                Freaky  2022
# 80327433   ITZY (있지)                 마.피.아. In the morning  2021
# 80327433   ITZY (있지)                       Sorry Not Sorry  2021
# 80327433   ITZY (있지)                                SHOOT!  2021
# 80327433   ITZY (있지)                            KIDDING ME  2021
# 80327433   ITZY (있지)                          TENNIS (0:0)  2021
# 80327433   ITZY (있지)                        Wild Wild West  2021
# 80327433   ITZY (있지)  Weapon (With 뉴니온, 플로어) (Prod. Czaer)  2022
# 80327433   ITZY (있지)                            믿지 (MIDZY)  2021
# 80327433   ITZY (있지)                               Voltage  2022
# 80327433   ITZY (있지)                        Blah Blah Blah  2022
#
#                                                        Lyric
# artist_id
# 80327433   [Yeah yeah\nLet's go\nLike what?\n자유로운 기분 I li...
# 80327433   [몰아치는 꿈 속으로 와\n눈 앞이 온통 나로 덮인 채로\n헤매게 될 환상 속으로\...
# 80327433   [Na na yeah uh\nNo no no no no no\n\n말꼬릴 붙잡고 늘...
# 80327433   [Shhhhhhh\nGuess who loves you 나야 나\nDo I show...
# 80327433   [Sorry not sorry\n안 미안해서 미안해\n가만있어도 태가 나는 걸 어째...
# 80327433   [Check my look\n걸음은 Like a dance\n좀 더 강하게 Choo...
# 80327433   [뻔한 변명은 좀 지겨워 Yeah\n(Blah blah)\n어설픈 네 표정이 좀 T...
# 80327433   [너와의 하루는 Match point\n긴장감 속에 몸이 안 움직여\n내 맘을 숨겨...
# 80327433   [찔리지 않게 조심해\n겉으론 가시들이 좀 많아 No no no\n배려가 좀 없어도...
# 80327433   [Weapon\nOH\nNever question it got no doubts\n...
# 80327433   [Trust me with your heart\nTrust me?\n방 한구석에 있...
# 80327433   [甘くみないで Just a girl\n아마쿠 미나이데 Just a girl\nNo ...
# 80327433   [なんだかDizzy 憂鬱な日々\n난다까dizzy 유-우츠나히비\n夢はFuzzy 言い...

# %% [markdown]
# # text basic cleaning

# %%
manual_sw = ['im', 'youre', "n't", '내', '나를', '나의', '너의', '난', '날', '내가', '너','나', '그', '니', '걸', '거야', '수', '다', '더',
'널', '네', '니가', '네가', '널', '너를', '넌', '내게', '이', 'l', 'u', '-',
'na', 'ah', 'e','m', 'uh', 'eh', 's', 'la', 'a', 'o', 'ta', 't', 'oh', 'du', 'yeah', '’', 'amp', 'comp',
'tu', 'ye', 'it', 'i', 'but', '너무', 'so', 'in', '또', 'roob', '왔니', '조금', '꼭', '이렇게',
'bo', 'peep', 'the','lolli', '정말', 'for', 'lollipop', '이제', 'on', 'muzik', 'lets', 'about', 
'처', 'amoled', '좀', '두', '닷닷닷닷닷', '어쩌다', '4', 'is', 'and', 'to', 'you', 'me','huh', 'now', 'ooop',
'just', 're', 'jumpin', 'dori', 'let', 'one', '아', 'ma', 'take', 'its', 'woo', 'this', 'that',
'whoo', 'get', 'are', 'dovey', 'hey', '어머어머', 'hush', '오', '나는', '너는', '슈가프리', '자꾸', '위', '아래', '것', '있어', '같아', '돼', 'ya', 'tickle', 'ha',
'way', '싶어', '같은', '오늘', '딱', '않아', '마', 'poppy','같아', 'day', 'be', 'rollin', '게', 'ba', 'hoo', 'ey', 'pa', 'ooh', 'swan', 'woo', 'ill', 'da', 'zu',
'zim', 'dam', 'dda', 'got', 'umpah','안', '건', '할','것도', 'at', 'yah', 'all', 'with', "ting", "mirror", "ring", "id", "nananana", "gas"]

# %%
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
# !pip install cleantext

# %%
import re
import string
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

from cleantext import clean
import string
import re


def clean_text(text):
    #changing to lowercase
    text = text.lower()
    text = text.replace('\r','')
    
    # removing #´s 
    text = re.sub(r'#[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    
    #indentation -> space
    text = re.sub(r'\n', ' ', text)
    
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '') 
    
    text = text.strip()
    
    #tokenization
    tokens = word_tokenize(text)   
    filtered_words = [w for w in tokens if w not in manual_sw]
    final = " ".join(cat for cat in filtered_words)
    
    return final

def kor_to_eng(text):

    text = text.replace("사랑", "love")
    text = text.replace("좋아", "like") # like has multiple meanings, so needs to n-gram as well
    text = text.replace("키스", "kiss")
    text = text.replace("입맞", "kiss")
    text = text.replace("뽀뽀", "kiss")
    text = text.replace("터치", 'touch')
    text = text.replace("안아", 'hug')
    text = text.replace("원해", "want")
    text = text.replace("원하", "want")
    text = text.replace("밤", "night")
    
    #gender-specific
    text = text.replace("남자", "man")
    text = text.replace("소년", 'boy')
    text = text.replace("오빠", "oppa")
    text = text.replace("그의", 'him')
    text = text.replace("그에게", 'him')
    text = text.replace("그와", 'him')
    text = text.replace("그를", 'him')
    text = text.replace("그가", 'him')
    text = text.replace("그는", 'him')
    text = text.replace("놈", 'guy')
    
    text = text.replace("소녀", "so-nyeo") #young girl (少女)
    text = text.replace("여자", "woman")
    text = text.replace("그녀", 'her')
    
# want & girl should be dealt with n-grams because the meaning is completely different 
#between English and Korean
    
    #돈 (money)
      
    return text


def by_year(df):
    df['cleaned_lyrics'] = df.Lyric.apply(clean_text)
    df['final_lyrics'] = df.cleaned_lyrics.apply(kor_to_eng)
    df.drop(columns = ['Lyric', 'cleaned_lyrics'], inplace = True)# bp_df
    df = df.groupby(['year']).sum()[['final_lyrics']]
    return df

# %% [markdown]
# # By year

# %%
# nltk.download('punkt')

# %%
# replace blackpink with other artists
by_year = by_year(itzy_df)
by_year
# Out:
#                                            final_lyrics
# year
# 2019  people look they tell 외모만 보고 날라리 같대요 what 신경 써...
# 2020  잔소리는 stop 알아서 할게 뭐가 되든 알아서 테니까 do what wan 평범하...
# 2021  loco 미친다는 말이 이해 간달까 gettin loco loco gosh 이건 달...
# 2022  go like what 자유로운 기분 like 고민 따윈 already done d...

# %%
def words_by_year(year):
    df_by_year = by_year.loc[year, :]
    df_2 = " ".join(cat for cat in df_by_year)
    return df_2

# %%
# df_2015 = words_by_year(2015)
# df_2016 = words_by_year(2016)
# df_2017 = words_by_year(2017)
# df_2018 = words_by_year(2018)
df_2019 = words_by_year(2019)
df_2020 = words_by_year(2020)
df_2021 = words_by_year(2021)
df_2022 = words_by_year(2022)

# %%
# replace blackpink with other artists
itzy_total = " ".join(cat for cat in itzy_df.final_lyrics)
itzy_total
# Out:
# 'go like what 자유로운 기분 like 고민 따윈 already done done 색안경 끼고 보는 죄지 thats not my fault woah told dont care 멋대로 갈 필요 없어 order dont need no guidance makin my my up run top 언제든 straight up 원래 두려운 없어 상관없어 call trouble or can call weirdo 나로 살고 턱 끝을 치켜올린 채로 가질 듯한 attitude 그거면 put my sneakers 하나 둘 ready set go put my sneakers put em up put em up put my sneakers 하나 둘 ready set go 멀리 가보자고 put em up put em up 기다리던 순간 stand up stand up 빨리 뛰는 심장 dont stop dont stop loose 불태워 지금 my youth party aint started 시작도 했어 요즘 꽂힌 말이 하나 있지 my best yet come 상관없어 call trouble or can call weirdo 나로 살고 턱 끝을 치켜올린 채로 가질 듯한 attitude 그거면 put my sneakers 하나 둘 ready set
inkin us city 한복판 잠들지 못한 빌딩 숲의 firefly 있기에 여기 by my side 울지 않을래 hold tight hold tight 솔직히 말하면 있잖아 보며 버텨 like domino domino 멋대로 무너질 수는 없다고 like domino domino same feeling 너와 we aint falling 서로의 힘이 견뎌 like domino domino 하나 둘 사그라든 빌딩 조명 속에 꺼지지 않는 불빛 my head talkin talkin us 다른 듯 나와 닮아 있는 봐 있을게 여기 by your side 알 hold tight hold tight 말하지 않아도 있잖아 보며 버텨 like domin ...

# %% [markdown]
# # wordcloud

# %%
# !pip install wordcloud

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %%
def word_cloud_year(df):
    word_cloud = WordCloud(font_path='Binggrae', width = 1000, height = 300, 
    colormap='BuPu', max_words=100, collocations = False).generate(df)

    plt.figure(figsize = (10,8))
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## wordcloud by year

# %%
# word_cloud_year(df_2015)

# %%
# word_cloud_year(df_2016)

# %%
# word_cloud_year(df_2017)

# %%
# word_cloud_year(df_2018)

# %%
word_cloud_year(df_2019)

# %%
word_cloud_year(df_2020)

# %%
word_cloud_year(df_2021)

# %%
word_cloud_year(df_2022)

# %% [markdown]
# ## total wordcloud

# %%
word_cloud_year(itzy_total)

# %% [markdown]
# # word ranking

# %%
def word_ranking(df_year):

    wordlist = df_year.split()
    wordfreq = [wordlist.count(p) for p in wordlist]
    freqdict = dict(list(zip(wordlist,wordfreq)))

    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    
    df = pd.DataFrame(aux)
    df = df.rename(columns = {0: 'frequency', 1:'keyword'})
    
    return df[:200]

# %%
#replace 'blackpink_total' - > '@@@@@@_total'

keyword_total = word_ranking(itzy_total)
keyword_total
# Out:
#      frequency   keyword
# 0          175        up
# 1          167      like
# 2          146      what
# 3          132        my
# 4          129        no
# ..         ...       ...
# 195          9        느낌
# 196          9        놀아
# 197          9       놀라지
# 198          9        그게
# 199          9  yaiyaiya
#
# [200 rows x 2 columns]

# %%
# word_2015 = word_ranking(df_2015)

# %%
# word_2016 = word_ranking(df_2016)

# %%
# word_2017 = word_ranking(df_2017)

# %%
# word_2018 = word_ranking(df_2018)

# %%
word_2019 = word_ranking(df_2019)

# %%
word_2020 = word_ranking(df_2020)

# %%
word_2021 = word_ranking(df_2021)

# %%
word_2022 = word_ranking(df_2022)

# %% [markdown]
# ### plot

# %%
keyword_25 = keyword_total[:25]
keyword_25
# Out:
#     frequency keyword
# 0         175      up
# 1         167    like
# 2         146    what
# 3         132      my
# 4         129      no
# 5         116    dont
# 6         115    want
# 7          85    love
# 8          82      we
# 9          79    know
# 10         70     not
# 11         69     wan
# 12         56      달라
# 13         56     put
# 14         56      do
# 15         55    your
# 16         55      go
# 17         52  twenty
# 18         51       해
# 19         51    make
# 20         48   swipe
# 21         46    blah
# 22         42    boom
# 23         41   sorry
# 24         41     gas

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
# %matplotlib inline

plt.rcParams['axes.unicode_minus']=False

# Initialize the matplotlib figure
plt.figure(figsize=(13,5))
plt.rcParams["font.family"] = "AppleGothic"

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(3, 10))

# # Load the example car crash dataset
# keywords = sns.load_dataset("keyword_total").sort_values("frequency", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="frequency", y="keyword", data=keyword_25, color="pink")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 250), ylabel="",
       xlabel="Itzy keywords total")
sns.despine(left=True, bottom=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## word frequency

# %%
def word_by_years(text, word):
    num_of_word = text.count(word)
    len_of_df = len(text)
    ratio = num_of_word / len_of_df *100
    return round(ratio, 3)

# %%
by_year['love'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "love"))
by_year['kiss'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "kiss"))
by_year['touch'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "touch"))
by_year['feel'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "feel"))
by_year['like'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "like"))
by_year['baby'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "baby"))
by_year['night'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "night"))
by_year['my'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "my"))

by_year['so-nyo'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "nyeo"))
by_year['woman'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "woman"))

by_year['he/him/his'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "him"))
by_year['guy'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "guy"))
by_year['boy'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "boy"))
by_year['man'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "man"))
by_year['oppa'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "oppa"))
by_year['mr'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "mr"))

by_year['want'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "wan"))

by_year['girl'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "girl"))
by_year['girls'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "girls"))
by_year['noona'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "noona"))
by_year['her'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "her"))
by_year['lady'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "lady"))

# %% [markdown]
# ## plot

# %%
keywords_df = by_year.drop(columns=['final_lyrics'])
keywords_df = keywords_df.iloc[:-1]
keywords_df
# Out:
#        love  kiss  touch   feel   like   baby  night     my  so-nyo  woman  \
# year
# 2019  0.245   0.0   0.00  0.000  0.450  0.000  0.082  0.634     0.0    0.0
# 2020  0.266   0.0   0.01  0.138  0.562  0.059  0.039  0.128     0.0    0.0
# 2021  0.321   0.0   0.00  0.074  0.301  0.100  0.067  0.140     0.0    0.0
#
#       ...    boy  man  oppa   mr   want   girl  girls  noona    her  lady
# year  ...
# 2019  ...  0.000  0.0   0.0  0.0  0.756  0.020   0.02    0.0  0.368   0.0
# 2020  ...  0.030  0.0   0.0  0.0  0.552  0.049   0.03    0.0  0.118   0.0
# 2021  ...  0.007  0.0   0.0  0.0  0.154  0.000   0.00    0.0  0.134   0.0
#
# [3 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame

plt.figure(figsize = (30,10))

plt.plot(keywords_df['love'], label = 'love', color = 'pink')
# plt.plot(keywords_df['kiss'], label = 'kiss')
# plt.plot(keywords_df['touch'], label = 'touch')
plt.plot(keywords_df['like'], label = 'like')
# plt.plot(keywords_df['woman'], color='red', label = 'woman')
plt.plot(keywords_df['he/him/his'], linestyle='dashed', label = 'he/him/his')
plt.plot(keywords_df['boy'], linestyle='dashed', label = 'boy')
plt.plot(keywords_df['man'], linestyle='dashed', label = 'man')

plt.plot(keywords_df['girl'], label = 'girl') #mostly related to hetero-normative term
plt.plot(keywords_df['girls'], label = 'girls') #mostly related to women empowerment(girlhood)
# plt.plot(keywords_df['so-nyo'], label = 'sonyo') - not significant
plt.plot(keywords_df['baby'], label = 'baby')
# plt.plot(keywords_df['feel'], label = 'feel')
# plt.plot(keywords_df['her'], label = 'her')
# plt.plot(keywords_df['why'], label = 'why')
plt.plot(keywords_df['want'], label = 'want')
plt.plot(keywords_df['night'], label = 'night', color = 'black')

plt.legend(loc='upper left')
plt.xlabel("Year")
plt.ylabel("Keywords")
plt.show()
