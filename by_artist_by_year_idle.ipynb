# %% [markdown]
# # Data Prep

# %%
import pandas as pd

# %%
#whole dataframe
gg_df = pd.read_csv('gg_final_dataframe.csv', index_col = 'artist_id')

# %%
#Select an artist
idle_df = gg_df[gg_df['artist_x']=='(여자)아이들'][['artist_x', 'song_name', 'year', 'Lyric']]
idle_df
# Out:
#           artist_x                               song_name  year  \
# artist_id
# 20056456   (여자)아이들                                  TOMBOY  2022
# 20056456   (여자)아이들                                  MY BAG  2022
# 20056456   (여자)아이들                                   말리지 마  2022
# 20056456   (여자)아이들                            VILLAIN DIES  2022
# 20056456   (여자)아이들                                  ESCAPE  2022
# 20056456   (여자)아이들                                    LIAR  2022
# 20056456   (여자)아이들                                 ALREADY  2022
# 20056456   (여자)아이들                                POLAROID  2022
# 20056456   (여자)아이들                                    Nxde  2022
# 20056456   (여자)아이들                                  Change  2022
# 20056456   (여자)아이들                                    LOVE  2022
# 20056456   (여자)아이들                                   Reset  2022
# 20056456   (여자)아이들                                     조각품  2022
# 20056456   (여자)아이들                           DARK (X-file)  2022
# 20056456   (여자)아이들                                  LATATA  2018
# 20056456   (여자)아이들                                    MAZE  2018
# 20056456   (여자)아이들                                   알고 싶어  2018
# 20056456   (여자)아이들                                 달라($$$)  2018
# 20056456   (여자)아이들                                    들어줘요  2018
# 20056456   (여자)아이들                           DON'T TEXT ME  2018
# 20056456   (여자)아이들                      덤디덤디 (DUMDi DUMDi)  2020
# 20056456   (여자)아이들                                    한(一)  2018
# 20056456   (여자)아이들                                    LION  2020
# 20056456   (여자)아이들                               Oh my god  2020
# 20056456   (여자)아이들                                     사랑해  2020
# 20056456   (여자)아이들                                   Maybe  2020
# 20056456   (여자)아이들                Oh my god (English Ver.)  2020
# 20056456   (여자)아이들                                   Uh-Oh  2019
# 20056456   (여자)아이들                                   화(火花)  2021
# 20056456   (여자)아이들                                    MOON  2021
# 20056456   (여자)아이들                                  DAHLIA  2021
# 20056456   (여자)아이들                                    한(寒)  2021
# 20056456   (여자)아이들                                    LOST  2021
# 20056456   (여자)아이들                           Where is love  2021
# 20056456   (여자)아이들                                Senorita  2019
# 20056456   (여자)아이들                                  싫다고 말해  2019
# 20056456   (여자)아이들                        What's Your Name  2019
# 20056456   (여자)아이들                          Blow Your Mind  2019
# 20056456   (여자)아이들                                     주세요  2019
# 20056456   (여자)아이들                               POP/STARS  2018
# 20056456   (여자)아이들                           i'M THE TREND  2020
# 20056456   (여자)아이들                                    MORE  2020
# 20056456   (여자)아이들                             THE BADDEST  2020
# 20056456   (여자)아이들           Last Dance (Prod. GroovyRoom)  2021
# 20056456   (여자)아이들              싫다고 말해 (Nightmare Version)  2019
# 20056456   (여자)아이들                    TOMBOY (R3HAB Remix)  2022
# 20056456   (여자)아이들                                 Help Me  2019
# 20056456   (여자)아이들                                    Show  2020
# 20056456   (여자)아이들  HWAA (Dimitri Vegas & Like Mike Remix)  2021
#
#                                                        Lyric
# artist_id
# 20056456   [Look at you 넌 못 감당해 날\nYa took off hook\n기분은 ...
# 20056456   [Red five diamonds in my bag\nIf you wanna see...
# 20056456   [약에 취해버린 Feel\n널브러진 Luxury bag\n크게 찢어지는 Lip\n두...
# 20056456   [Once upon a time there was a villain\nWho is ...
# 20056456   [Look into the sky\nWhat do you see?\n저 멀리 별들 ...
# 20056456   [I've been woken up in different places\n습관처럼 ...
# 20056456   [I'm alone in this room for so so long\n너에 대한 ...
# 20056456   [철없는 우릴 사진에 담아서\n잊지 않게 간직하고 싶어 난\nIn my pocket...
# 20056456   [Why you think that 'bout nude\n'Cause your vi...
# 20056456   [Woke up in another new day\nSomething has cha...
# 20056456   [Hey ex-boyfriend\n자꾸 인스타 염탐하던데\nYou hope to g...
# 20056456   [그만하자 그 말이 다야?\n어쩜 넌 끝까지 못됐니\n그래 그만하자 차라리 잘 됐다...
# 20056456   [I wanna be 그 작품이\n다들 미쳤다지만\n이미 You are my art...
# 20056456   [Baby why you down?\nWanna take a puff on my j...
# 20056456   [기나긴 너와 이 밤을 너와\n이렇게 너와\n기다린 너와 시간을 너와\n이렇게 너와...
# 20056456   [너의 깊은 그 눈빛이 날 데려가 저 멀리\n누군가 맘에 들 때 더 신비롭게 궁금하...
# 20056456   [What's in your house?\nWhat's in your house?\...
# 20056456   [Knock knock 들어간다 Soyeon이\n머리 위에 Spotlight\n저기...
# 20056456   [한마디 떼어내기 너무 힘들죠\n난 여기 있는데 기다리는데\n그대는 보이지 않죠\n...
# 20056456   [오늘따라 이상하리만큼\n잠이 오지 않아 괜히 뒤척여\n익숙한 듯 어떻게 연락해 어...
# 20056456   [뜨거운 태양에 살짝 미친 난\n쉽게 두 볼이 빨개지고\n그러다 어질어질 달아오른 ...
# 20056456   [Do you remember you remember\nRemember what y...
# 20056456   [Ooh I'm a lion I'm a queen 아무도\n그래 Ooh 날 가둘 수...
# 20056456   [눈부신 하늘에 시선을 가린 채\n네 품 안에 안기네\n흐르는 음악에 정신을 뺏긴 ...
# 20056456   [너 아찔하게 웃지 마\n좀 위험하니까 (Danger)\n또 뚫어지게 보지 마\n너...
# 20056456   [유독 추웠던 밤에 잠을 설쳤는지\n잠이 깬 밝은 아침 어둠이 가득한 너\n뭐 그리...
# 20056456   [Nothing can pull me away\nFrom your embrace\n...
# 20056456   [Uh oh 거기 누군가요\nUh oh 나를 안다고요\nUh oh 난 잊어버렸죠 버...
# 20056456   [차디찬 한겨울이 덮친 듯\n시간은 다 얼어버리고\n잔인한 그 바람이 남긴 듯한\n...
# 20056456   [달이 밝은 밤 숨지 못한 나\n붉은색의 달빛에 내 눈물이\n내 표정이 보여\nDo...
# 20056456   [너무 아름다워\n그저 널 눈으로 바라만 봐도 반하네\n스쳐 지나가도\n달콤한 향기...
# 20056456   [끝이 없구나 차디찬 계절 참 길구나\n꽃 하나 없구나 그날의 나 여전하구나\n잊겠...
# 20056456   [눈부신 햇빛 손으로 가리면 어두워질까\n얼룩진 추억에 너를 가리면 잊혀질까\n혹시...
# 20056456   [어두운 밤 창가의 바람을 머금다\n문득 네가 떠올라 가볍게 웃어 난\n무너졌던 기...
# 20056456   [그대여 왜 그렇게 쳐다보나요?\n아무 말도 건네주지 않고\n나의 눈을 피하지도 않...
# 20056456   [싫다고 말해\n사랑하지 않는다고 말해 봐\n내 맘이 떠날 거 같이\n네가 미워질 ...
# 20056456   [아픈 말 아픈 맘 모두 구름 가득 담아\n내려봐 잊어봐 한밤의 꿈처럼 말이야\n우...
# 20056456   [Don’t wanna be unsteady\nDon’t wanna be uncer...
# 20056456   [안경 낀 바보 같은 얼굴도\n자다 일어난 눈곱 낀 모습도\n많이 먹어 배 나온 요...
# 20056456   [You know who it is\nComing 'round again\nYou ...
# 20056456   [I don't need a perfume 향수를 뿌리지 않아도\n주변에 항상 나비...
# 20056456   [K/DA\nShould we show 'em how we do it everyda...
# 20056456   [Baddest do what the baddest do\nThe baddest d...
# 20056456   [죽을 듯이 또 울어도 찢어질 듯이 불러도\n벼랑 끝에 서 있어도 더 이상 상관없는...
# 20056456   [싫다고 말해\n사랑하지 않는다고 말해 봐\n내 맘이 떠날 거 같이\n네가 미워질 ...
# 20056456   [Look at you 넌 못 감당해 날\nYa took off hook\n기분은 ...
# 20056456   [Oh uh woo uh\nUh woo uh uh\nOh uh woo uh\nBab...
# 20056456   [내 주위를 스쳐간 그 누군가 말했지\n우리네 화려한 인생은 일 막의 쇼와 같다고\...
# 20056456   [In the frozen dark of your winter\nThe coldes...

# %% [markdown]
# # text basic cleaning

# %%
manual_sw = ['im', 'youre', "n't", '내', '나를', '나의', '너의', '난', '날', '내가', '너','나', '그', '니', '걸', '거야', '수', '다', '더',
'널', '네', '니가', '네가', '널', '너를', '넌', '내게', '이', 'l', 'u', '-',
'na', 'ah', 'e','m', 'uh', 'eh', 's', 'la', 'a', 'o', 'ta', 't', 'oh', 'du', 'yeah', '’', 'amp', 'comp',
'tu', 'ye', 'it', 'i', 'but', '너무', 'so', 'in', '또', 'roob', '왔니', '조금', '꼭', '이렇게',
'bo', 'peep', 'the','lolli', '정말', 'for', 'lollipop', '이제', 'on', 'muzik', 'lets', 'about', 
'처', 'amoled', '좀', '두', '닷닷닷닷닷', '어쩌다', '4', 'is', 'and', 'to', 'you', 'me','huh', 'now', 'ooop',
'just', 're', 'jumpin', 'dori', 'let', 'one', '아', 'ma', 'take', 'its', 'woo', 'this', 'that',
'whoo', 'get', 'are', 'dovey', 'hey', '어머어머', 'hush', '오', '나는', '너는', '슈가프리', '자꾸', '위', '아래', '것', '있어', '같아', '돼', 'ya', 'tickle', 'ha',
'way', '싶어', '같은', '오늘', '딱', '않아', '마', 'poppy','같아', 'day', 'be', 'rollin', '게', 'ba', 'hoo', 'ey', 'pa', 'ooh', 'swan', 'woo', 'ill', 'da', 'zu',
'zim', 'dam', 'dda', 'got', 'umpah','안', '건', '할','것도', 'at', 'yah', 'all', 'with']

# %%
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
# !pip install cleantext

# %%
import re
import string
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

from cleantext import clean
import string
import re


def clean_text(text):
    #changing to lowercase
    text = text.lower()
    text = text.replace('\r','')
    
    # removing #´s 
    text = re.sub(r'#[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    
    #indentation -> space
    text = re.sub(r'\n', ' ', text)
    
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '') 
    
    text = text.strip()
    
    #tokenization
    tokens = word_tokenize(text)   
    filtered_words = [w for w in tokens if w not in manual_sw]
    final = " ".join(cat for cat in filtered_words)
    
    return final

def kor_to_eng(text):

    text = text.replace("사랑", "love")
    text = text.replace("좋아", "like") # like has multiple meanings, so needs to n-gram as well
    text = text.replace("키스", "kiss")
    text = text.replace("입맞", "kiss")
    text = text.replace("뽀뽀", "kiss")
    text = text.replace("터치", 'touch')
    text = text.replace("안아", 'hug')
    text = text.replace("원해", "want")
    text = text.replace("원하", "want")
    text = text.replace("밤", "night")
    
    #gender-specific
    text = text.replace("남자", "man")
    text = text.replace("소년", 'boy')
    text = text.replace("오빠", "oppa")
    text = text.replace("그의", 'him')
    text = text.replace("그에게", 'him')
    text = text.replace("그와", 'him')
    text = text.replace("그를", 'him')
    text = text.replace("그가", 'him')
    text = text.replace("그는", 'him')
    text = text.replace("놈", 'guy')
    
    text = text.replace("소녀", "so-nyeo") #young girl (少女)
    text = text.replace("여자", "woman")
    text = text.replace("그녀", 'her')
    
# want & girl should be dealt with n-grams because the meaning is completely different 
#between English and Korean
    
    #돈 (money)
      
    return text


def by_year(df):
    df['cleaned_lyrics'] = df.Lyric.apply(clean_text)
    df['final_lyrics'] = df.cleaned_lyrics.apply(kor_to_eng)
    df.drop(columns = ['Lyric', 'cleaned_lyrics'], inplace = True)# bp_df
    df = df.groupby(['year']).sum()[['final_lyrics']]
    return df

# %% [markdown]
# # By year

# %%
# nltk.download('punkt')

# %%
# replace blackpink with other artists
by_year = by_year(idle_df)
by_year
# Out:
#                                            final_lyrics
# year
# 2018  기나긴 너와 night을 너와 너와 기다린 너와 시간을 너와 너와 어둠 속 red ...
# 2019  거기 누군가요 안다고요 잊어버렸죠 버렸죠 너도 웃기지 않나요 당황스럽네요 친한 척 ...
# 2020  뜨거운 태양에 살짝 미친 쉽게 볼이 빨개지고 그러다 어질어질 달아오른 헤엄을 치듯 ...
# 2021  차디찬 한겨울이 덮친 듯 시간은 얼어버리고 잔인한 바람이 남긴 듯한 어둠은 깊어 버...
# 2022  look 못 감당해 took off hook 기분은 coke like brrr lo...

# %%
def words_by_year(year):
    df_by_year = by_year.loc[year, :]
    df_2 = " ".join(cat for cat in df_by_year)
    return df_2

# %%
# df_2015 = words_by_year(2015)
# df_2016 = words_by_year(2016)
# df_2017 = words_by_year(2017)
df_2018 = words_by_year(2018)
df_2019 = words_by_year(2019)
df_2020 = words_by_year(2020)
df_2021 = words_by_year(2021)
df_2022 = words_by_year(2022)

# %%
# replace blackpink with other artists
idle_total = " ".join(cat for cat in idle_df.final_lyrics)
idle_total
# Out:
# 'look 못 감당해 took off hook 기분은 coke like brrr look my toe ex 이름 tattoo drink up 싫다 해도 like why cranky boy 뭘 그리 찡그려 do want blond barbie doll not here not doll 미친 연이라 말해 whats loss 사정없이 까보라고 youll lose love 그깟 거 따위 몸에 상처 하나도 어림없지 썩은 향수나 뿌릴 바엔 tomboy umm umm tomboy umm my attitude tomboy dont wan play ping pong would rather film tik tok your mom raised as prince queendom right like dancing love friends sometimes we swear without cigarettes like drinking whiskey wont change what hell 미친 척이라 말해 whats loss 사정없이 씹으라고 lost love 그깟 거 따위 눈에 눈물 한 방울 어림없지 하찮은 말에 미소나 지을 바엔 tomboy umm umm tomboy umm my attitude tomboy said song right youll what mean tomboy three two neither man nor woman man nor woman neither man nor woman dle neither man nor woman man nor woman neither man nor woman loving tomboy red five diamonds my bag if wan see dance beat like my mama saw my god dang ok show whats my bag red five diamonds my bag if wan see dance beat like my mama saw my god dang ok show whats my bag know like my voice는 말해 뭐 해 god dang like 태생부터 많은 money 관심 없지 싸가지 없는 무대의 못된 범인의 눈빛 fantasy란 말은 빼고 금지 글러 먹은 감 모두 위한 밥 독한 vibe sugar high 맛 봐라 모두 die rum rum rum rumble crumble voice는 drum에도 no lose no no no lovely bumblebee 그냥 훅 들어갈 뿐 해 two never had 겁 k giant dog 아차 하고 쓰다듬은 다쳐 이건 어쩜 범 value my love 그만 두들겨 머리 빈 멍청이들과는 노는 물이 전혀 달라 know red five diamonds my bag if wan see dance beat like my mama saw my god dang ok show whats my bag red five diamonds my bag if wan see dance beat like my mama saw my god dang ok show whats my bag 가벼운 no no 공포에는 덤덤 나쁜 guy에겐 월월 덤벼봐라 come come cool lady 유일무이 캐릭 벌벌 떠는 언니들 사이 boss baby 넘치는 jealousy thats too early 피부부터 young한 것은 언급하기도 귀찮네 존재가 princess 어쩌면 범죄 넘치는 bullet 맘을 관통해 향기는 like rose beautiful red 화가 가시의 그대 blood 아직 읽지 않은 연락들은 앞으로도 읽지 않을 거니 헛된 희망들은 저기 버려두길 know say no red five diamonds my bag if wan see dance beat like my mama saw my god dang ok show whats my bag red five diamonds my bag if wan see dance beat like my mama saw my god dang ok show whats my bag 약에 취해버린 feel 널브러진 luxury bag 크게 찢어지는 lip 눈은 번져 like smokey baby knew 떠나니 잘 가라지 not crazy 예쁜 입에서 이런 욕이 뭐 always nasty 바랐니 끝까지 멍청한 천사였길 broke my heart locked my love 어이없어 눈물이 나네 아니 전혀 괜찮아 put leather jacket mama dont ever ever stop 어떤 짓을 벌였든 mama dont ever ever stuck 말리지 woah woah surprise your pants bought 검은 양말 벗어 주길 her gift minipill want고 조절 못 하니 hell no does he know any bed red car scolded by daddy out of company looking forward your wedding broke my heart locked my love 뻔뻔해서 소름이 돋네 아직 전혀 괜찮아 fire last rocket mama dont ever ever stop 어떤 짓을 벌였든 mama dont ever ever stuck 말리지 woah woah 때려치워 좋은 끝 그까짓 거 알아 이불 발로 차며 후회하지 뭐 원래 이래 몰랐겠지만 screw dummy know look forward know too emotional 아무도 말리지 넋이 나가버린 feel 엎질러진 ice coffee 휘어지는 red lip 싫어했던 smokey once upon time there was villain who villain 혀 안에 가득 찬 사탕 strawberry 이게 마지막 만찬인지 따갑게 달콤해 멍청해 흙투성이 쟨 멀쩡해 몇 발을 쏴도 총엔 맞지 okay why dont love 이것 봐 이리 아름다운데 미친 소설의 끝은 대체 언제쯤 if villain dies okay bullet love die heroine mine never die even if your sad ending heroine mine never die even if your sad ending put down want dead fact dont even know well never cry was pain yesterday as well cuz of her who villain 악당이 나였네 모든 망치는 her를 미워했는데 소설 속 악당은 나였네 yo god or author goin hell not alone 뵈는 없어진 play는 바꿔버릴 결론 yo god or author goin hell not alone no no no why do love her 이것 봐 늘 아프게 하는데 미친 소설의 끝은 대체 언제쯤 if villain dies okay bullet love die heroine mine never die even if your sad ending heroine mine never die even if your sad ending 멍청하게 흘러가게 두지 재밌는 ending을 잘 봐 악역의 웃음에 우울한 마지막 장 right right write never die look into sky what do see 저 멀리 별들 like your eyes theyre pretty 달빛 어둠을 벗고 비춰진 모습 아름답게만 보여 please smile 지금처럼 울지 않았으면 슬퍼하지 않았으면 해 그늘진 시간 매일 외로운 night 늘 혼자 견디지 말고 my hand 우는 것보다 웃음소리가 어울리는데 baby there 어디든 데려갈게 coming 아무 생각 없이 달려가 run run right by your side 또다시 넘어져도 괜찮아 잠시 내려놔도 원래 힘든 거래 모두가 마치 유난인 것처럼 눈치를 보며 그냥 버틸까도 하다가 때려치워 버거워 순간 행복해질래 지각이래도 잠깐 멈춰서 쉴래 책임져야겠지 현실과 미래 인생 몰라 이럴 땐 너에게로 escape 그늘진 시간 매일 외로운 night 늘 혼자 견디지 말고 my hand 우는 것보다 웃음소리가 어울리는데 baby there 어 ...

# %% [markdown]
# # wordcloud

# %%
# !pip install wordcloud

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %%
def word_cloud_year(df):
    word_cloud = WordCloud(font_path='Binggrae', width = 1000, height = 300, 
    colormap='BuPu', max_words=100, collocations = False).generate(df)

    plt.figure(figsize = (10,8))
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## wordcloud by year

# %%
# word_cloud_year(df_2015)

# %%
# word_cloud_year(df_2016)

# %%
# word_cloud_year(df_2017)

# %%
word_cloud_year(df_2018)

# %%
word_cloud_year(df_2019)

# %%
word_cloud_year(df_2020)

# %%
word_cloud_year(df_2021)

# %%
word_cloud_year(df_2022)

# %% [markdown]
# ## total wordcloud

# %%
word_cloud_year(idle_total)

# %% [markdown]
# # word ranking

# %%
def word_ranking(df_year):

    wordlist = df_year.split()
    wordfreq = [wordlist.count(p) for p in wordlist]
    freqdict = dict(list(zip(wordlist,wordfreq)))

    aux = [(freqdict[key], key) for key in freqdict]
    aux.sort()
    aux.reverse()
    
    df = pd.DataFrame(aux)
    df = df.rename(columns = {0: 'frequency', 1:'keyword'})
    
    return df[:200]

# %%
#replace 'blackpink_total' - > '@@@@@@_total'

keyword_total = word_ranking(idle_total)
keyword_total
# Out:
#      frequency keyword
# 0          204    love
# 1          138    your
# 2          134      my
# 3           82    like
# 4           72   whats
# ..         ...     ...
# 195          7      싶지
# 196          7       순
# 197          7     마지막
# 198          7      듯이
# 199          7      눈을
#
# [200 rows x 2 columns]

# %%
# word_2015 = word_ranking(df_2015)

# %%
# word_2016 = word_ranking(df_2016)

# %%
# word_2017 = word_ranking(df_2017)

# %%
word_2018 = word_ranking(df_2018)

# %%
word_2019 = word_ranking(df_2019)

# %%
word_2020 = word_ranking(df_2020)

# %%
word_2021 = word_ranking(df_2021)

# %%
word_2022 = word_ranking(df_2022)

# %% [markdown]
# ### plot

# %%
keyword_25 = keyword_total[:25]
keyword_25
# Out:
#     frequency keyword
# 0         204    love
# 1         138    your
# 2         134      my
# 3          82    like
# 4          72   whats
# 5          60    dont
# 6          44      we
# 7          43      if
# 8          42    know
# 9          40   house
# 10         40    down
# 11         38      do
# 12         37   never
# 13         36      up
# 14         35    want
# 15         35      no
# 16         34     not
# 17         31      go
# 18         28       거
# 19         28    name
# 20         28  latata
# 21         28     god
# 22         28    baby
# 23         27    what
# 24         27     wan

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
# %matplotlib inline

plt.rcParams['axes.unicode_minus']=False

# Initialize the matplotlib figure
plt.figure(figsize=(13,5))
plt.rcParams["font.family"] = "AppleGothic"

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(3, 10))

# # Load the example car crash dataset
# keywords = sns.load_dataset("keyword_total").sort_values("frequency", ascending=False)

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="frequency", y="keyword", data=keyword_25, color="pink")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 250), ylabel="",
       xlabel="Idle keywords total")
sns.despine(left=True, bottom=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## word frequency

# %%
def word_by_years(text, word):
    num_of_word = text.count(word)
    len_of_df = len(text)
    ratio = num_of_word / len_of_df *100
    return round(ratio, 3)

# %%
by_year['love'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "love"))
by_year['kiss'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "kiss"))
by_year['touch'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "touch"))
by_year['feel'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "feel"))
by_year['like'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "like"))
by_year['baby'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "baby"))
by_year['night'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "night"))
by_year['my'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "my"))

by_year['so-nyo'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "nyeo"))
by_year['woman'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "woman"))

by_year['he/him/his'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "him"))
by_year['guy'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "guy"))
by_year['boy'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "boy"))
by_year['man'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "man"))
by_year['oppa'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "oppa"))
by_year['mr'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "mr"))

by_year['want'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "wan"))

by_year['girl'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "girl"))
by_year['girls'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "girls"))
by_year['noona'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "noona"))
by_year['her'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "her"))
by_year['lady'] = by_year.final_lyrics.apply(lambda x: word_by_years(x, "lady"))

# %% [markdown]
# ## plot

# %%
keywords_df = by_year.drop(columns=['final_lyrics'])
keywords_df = keywords_df.iloc[:-1]
keywords_df
# Out:
#        love  kiss  touch   feel   like   baby  night     my  so-nyo  woman  \
# year
# 2018  0.344  0.00  0.000  0.026  0.146  0.093  0.172  0.199     0.0  0.013
# 2019  0.797  0.00  0.000  0.095  0.228  0.171  0.038  0.095     0.0  0.000
# 2020  0.161  0.00  0.011  0.046  0.447  0.011  0.115  0.447     0.0  0.000
# 2021  0.667  0.02  0.000  0.000  0.059  0.000  0.177  0.314     0.0  0.000
#
#       ...    boy    man  oppa     mr   want   girl  girls  noona    her  lady
# year  ...
# 2018  ...  0.013  0.066   0.0  0.000  0.278  0.106    0.0    0.0  0.040   0.0
# 2019  ...  0.000  0.019   0.0  0.000  0.095  0.000    0.0    0.0  0.000   0.0
# 2020  ...  0.011  0.000   0.0  0.011  0.172  0.023    0.0    0.0  0.195   0.0
# 2021  ...  0.000  0.000   0.0  0.000  0.118  0.000    0.0    0.0  0.451   0.0
#
# [4 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame

plt.figure(figsize = (30,10))

plt.plot(keywords_df['love'], label = 'love', color = 'pink')
# plt.plot(keywords_df['kiss'], label = 'kiss')
# plt.plot(keywords_df['touch'], label = 'touch')
plt.plot(keywords_df['like'], label = 'like')
# plt.plot(keywords_df['woman'], color='red', label = 'woman')
plt.plot(keywords_df['he/him/his'], linestyle='dashed', label = 'he/him/his')
plt.plot(keywords_df['boy'], linestyle='dashed', label = 'boy')
plt.plot(keywords_df['man'], linestyle='dashed', label = 'man')

plt.plot(keywords_df['girl'], label = 'girl') #mostly related to hetero-normative term
plt.plot(keywords_df['girls'], label = 'girls') #mostly related to women empowerment(girlhood)
# plt.plot(keywords_df['so-nyo'], label = 'sonyo') - not significant
plt.plot(keywords_df['baby'], label = 'baby')
# plt.plot(keywords_df['feel'], label = 'feel')
# plt.plot(keywords_df['her'], label = 'her')
# plt.plot(keywords_df['why'], label = 'why')
plt.plot(keywords_df['want'], label = 'want')
plt.plot(keywords_df['night'], label = 'night', color = 'black')

plt.legend(loc='upper left')
plt.xlabel("Year")
plt.ylabel("Keywords")
plt.show()
