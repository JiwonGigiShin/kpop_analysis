# %%
# Day 5

# %% [markdown]
# ### Day 4

# %%
with open('day4.txt', 'r') as f:
     elves = f.readlines()
    
cleaning = [line.strip() for line in elves]

# %%
cleaning
# Out:
# ['2-5,15-90',
#  '42-93,43-57',
#  '71-95,72-81',
#  '19-92,2-93',
#  '21-92,57-93',
#  '57-75,76-76',
#  '66-92,14-76',
#  '4-97,5-96',
#  '22-50,22-51',
#  '10-43,42-43',
#  '50-59,60-60',
#  '81-86,86-94',
#  '86-98,82-99',
#  '44-63,44-62',
#  '36-65,42-89',
#  '2-86,14-85',
#  '51-51,48-52',
#  '41-55,10-55',
#  '3-99,3-96',
#  '62-64,38-63',
#  '24-80,80-98',
#  '13-67,7-47',
#  '22-78,21-91',
#  '3-92,26-91',
#  '97-98,86-98',
#  '17-90,16-91',
#  '4-96,97-97',
#  '33-46,44-47',
#  '98-98,44-96',
#  '9-36,7-13',
#  '17-91,18-90',
#  '1-37,4-37',
#  '19-58,18-58',
#  '42-43,11-42',
#  '9-98,10-97',
#  '6-22,5-6',
#  '9-12,13-61',
#  '4-16,17-24',
#  '37-45,36-38',
#  '62-86,61-61',
#  '8-41,8-40',
#  '35-91,35-98',
#  '84-85,72-84',
#  '40-90,41-91',
#  '47-58,31-59',
#  '30-80,22-31',
#  '87-89,58-90',
#  '13-25,14-25',
#  '23-54,52-53',
#  '4-89,5-88',
#  '3-99,1-2',
#  '4-54,3-53',
#  '4-33,5-52',
#  '50-92,49-50',
#  '72-98,71-97',
#  '7-27,26-27',
#  '10-49,39-78',
# ...

# %%
cleaning[0].split(',')
# Out:
# ['2-5', '15-90']

# %%
divided_lst = []

for i in range(len(cleaning)):
    divided = list(cleaning[i].split(','))
    divided_lst.append(divided)

# %%
divided_lst[0][0]
# Out:
# '2-5'

# %%
first=[]
second = []

for i in range(len(cleaning)):
    first_elf = divided_lst[i][0].split('-')
    second_elf = divided_lst[i][1].split('-') 
    
    first.append(first_elf)
    second.append(second_elf)

# %%
len(cleaning)
# Out:
# 1000

# %%
final_lst = []
for i in range(len(cleaning)):

    first_1 = int(first[i][0])
    first_2 = int(first[i][1])

    sec_1 = int(second[i][0])
    sec_2 = int(second[i][1])

    if (first_1 <= sec_1 and first_2>= sec_2) or (first_1 >= sec_1 and first_2 <= sec_2):
        final_lst.append(first)

# %%
len(final_lst)
# Out:
# 462

# %%
first_range = []
for a in range(1000):
    b = [i for i in range(int(first[a][0]), int(first[a][1])+1)]
    first_range.append(b)
    
    
sec_range = []
for a in range(1000):
    b = [i for i in range(int(second[a][0]), int(second[a][1])+1)]
    sec_range.append(b)

# %%
len(first_range)
# Out:
# 1000

# %%
def common_data(list1, list2):
    result = False
  
    # traverse in the 1st list
    for x in list1:
  
        # traverse in the 2nd list
        for y in list2:
    
            # if one common
            if x == y:
                result = True
                return result 
                  
    return result

# %%
lst_222=[]
for i in range(1000):
    lst_222.append(common_data(first_range[i], sec_range[i]))

# %%
final_lst_pt2 = [x for x in lst_222 if x==True]

# %%
len(final_lst_pt2)
# Out:
# 835

# %% [markdown]
# ### DAY 3

# %%
with open('day3.txt', 'r') as f:
    elves = f.readlines()
    
lines = [line.strip() for line in elves]

# %%
# first_half1 = abc[:len(abc)//2]
# second_half1 = abc[len(abc)//2:]

# for l in first_half1:
#     if l in second_half1:
#         print(len(l))

# %%
letters = []
for i in range(len(lines)):
    first_half = lines[i][:len(lines[i])//2]
    second_half = lines[i][len(lines[i])//2:]
    
    first_half_re = "".join(set(first_half))
    second_half_re = "".join(set(second_half))
    
    for l in first_half_re:
        if l in second_half_re:
            letters.append(l)

# %%
import string

# %%
alphabet_lst = list(string.ascii_letters)

# %%
# dict_alphabet = dict((i,j) for i,j in enumerate(alphabet_lst, start=1))

# %%
# hi = []
# for i in range(len(letters)):
#     numbers = list(dict_alphabet.keys())
#     alphabets = hi.append(list(dict_alphabet.values()).index(letters[i])+1)

# %%
# hi2 = []
# for i in range(len(letters)):
#     numbers = list(range(1,53))
#     alphabets = hi2.append(alphabet_lst.index(letters[i])+1)

# %%
def convert_to_number(lst):
    
    alphabet_lst = list(string.ascii_letters)
    
    numbers_lst_haha = []
    
    for i in range(len(lst)):
        numbers = list(range(1,53))
        alphabets = numbers_lst_haha.append(alphabet_lst.index(lst[i])+1)
        
    return numbers_lst_haha

# %% [markdown]
# # Part 2

# %%
chunks = [lines[x:x+3] for x in range(0, len(lines), 3)]

# %%
lstlst = []

for i in range(len(chunks)):
    first_sentence = chunks[i][0]
    second_sentence = chunks[i][1]
    third_sentence = chunks[i][2]
    
    first_half_ah = "".join(set(first_sentence))
    second_half_ah = "".join(set(second_sentence))
    third_half_ah = "".join(set(third_sentence))
    
    for l in first_half_ah:
        if l in second_half_ah and l in third_half_ah:
            lstlst.append(l)

# %%
a = convert_to_number(lstlst)

# %%
sum(a)
# Out:
# 2569

# %%
with open('요정.txt') as f:
    lines = [line.strip() for line in f.readlines()]


rules1 = {'A X':3+1, 'A Y':6+2, 'A Z':0+3, 'B X':0+1, 'B Y':3+2, 'B Z':6+3, 'C X':6+1, 'C Y':0+2, 'C Z':3+3}
rules2 = {'A X':0+3, 'A Y':3+1, 'A Z':6+2, 'B X':0+1, 'B Y':3+2, 'B Z':6+3, 'C X':0+2, 'C Y':3+3, 'C Z':6+1}

print(sum(rules1[i] for i in lines))
print(sum(rules2[i] for i in lines))

# %%
score2 = []
for i in lines:
    if i == 'A X':
        score2.append(3)
    if i == 'A Y':
        score2.append(4)
    if i == 'A Z':
        score2.append(8)
    if i == 'B X':
        score2.append(1)
    if i == 'B Y':
        score2.append(5)
    if i == 'B Z':
        score2.append(9)
    if i == 'C X':
        score2.append(2)
    if i == 'C Y':
        score2.append(6)
    if i == 'C Z':
        score2.append(7)

# %%
sum(score2)

# %%
len(score)

# %%
score = []
for i in elves:
    if i == 'A X\n':
        score.append(4)
    if i == 'A Y\n':
        score.append(8)
    if i == 'A Z\n':
        score.append(3)
    if i == 'B X\n':
        score.append(1)
    if i == 'B Y\n':
        score.append(5)
    if i == 'B Z\n':
        score.append(9)
    if i == 'C X\n':
        score.append(7)
    if i == 'C Y\n':
        score.append(2)
    if i == 'C Z\n':
        score.append(6)

# %%
sum(score)

# %%
1 : Rock, 
2 : Paper,
3 : Scissors


0 : Lose
3 : Draw
6 : Won
    
A rock
B paper
C scissors


X Rock
Y paper
Z Scissors

    
'A X\n' : 4
'A Y\n' : 
'A Z\n' : 
'B X\n' :
'B Y\n' :
'B Z\n' :
'C X\n'
'C Y\n'
'C Z\n'

# %%
with open('요정.txt', 'r') as f:
    elves = f.readlines()

# %%
elves

# %%
with open('요정.txt', 'r') as f:
    elves = [line.strip() for line in f]

# %%
elves

# %%
l_new = []

start_i = 0


for i in range(len(elves)):

    if (elves[i]==''):

        l_new.append(elves[start_i:i])
        start_i = i+1

l_new.append(elves[start_i:i+1])

print(l_new)

# %%
l_new

# %%
len(l_new)

# %%
l_new

# %%
#for i in len(l_new):
a = [int(x) for x in l_new[0]]
a

sum_lst = []

for i in range(236):
    sum_lst.append([int(x) for x in l_new[i]])

# %%
sum_lst

# %%
sum_lst_2 = []
for each in sum_lst:
    sum_lst_2.append(sum(each))

# %%
max(sum_lst_2)

# %%
sum_lst_2.index(68787)

# %%
! pip install pandas

# %%
import pandas as pd
a = pd.DataFrame(sum_lst_2)

# %%
a

# %%
b = a.tail(3)

# %%
b

# %%
b.sum()

# %%
url =

# %%
response.text()

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://adventofcode.com/2022/day/1/input'
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

requests.get()

# %%
soup

# %%
import requests
import os

COOKIE = os.environ.get("SESSION")

def get_data(day):
    response = requests.get(f'https://adventofcode.com/2022/day/{day}/input',
                            cookies={'session': COOKIE})
    raw_data = response.content.decode('UTF-8')
    return raw_data

# %%
raw_data = get_data(1)

# %%
raw_data
