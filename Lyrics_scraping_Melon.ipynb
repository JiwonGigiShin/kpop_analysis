# %% [markdown]
# # Module

# %%
import selenium
from selenium import webdriver as wd
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests
from itertools import repeat
from selenium.webdriver.common.by import By

# %% [markdown]
# # Chrome Driver

# %%
#open Chromedriver

driver = wd.Chrome('/chromedriver') #path
driver.maximize_window() #maximise the size of chrome window

#access to specific URL
url = 'https://www.melon.com/chart/index.htm'
driver.get(url)
# Out:
# /var/folders/hq/nqwncw9n70j0_vwz8bkfhkf80000gn/T/ipykernel_68502/3609011908.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('/chromedriver') #path

# %% [markdown]
# # Filter

# %%
#select chart finder
driver.find_element(By.XPATH, '//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()

# %%
# DECADE, YEAR, MONTH, GENRE

# Yearly Chart
driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/h4[3]/a').click()
time.sleep(2)

# %%
# Select Decade (2000s)
driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[3]/span/label').click()
time.sleep(2)

# %%
# Select Year (2005~2009) 
# 2005 = li[10],... 2009 = li[1]
driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[5]/span/label').click()
time.sleep(2)

# %%
# Select 'Domestic Chart'

driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[2]/span/label').click()
time.sleep(2)

# %%
# Click 'Search'

driver.find_element(By.XPATH, '//*[@id="d_srch_form"]/div[2]/button/span/span').click()

# %% [markdown]
# # html

# %%
# ! pip install lxml

# %%
html = driver.page_source #cf) requests.get(url)
soup = BeautifulSoup(html, 'lxml')

# %% [markdown]
# # Song title

# %%
soup.find_all('div', attrs = {'class': 'ellipsis rank01'})
# Out:
# [<div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','711627');" title="죄와벌 재생 - 새창">죄와벌</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','732512');" title="겁쟁이 재생 - 새창">겁쟁이</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','837567');" title="사랑했나봐 재생 - 새창">사랑했나봐</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','711626');" title="살다가 재생 - 새창">살다가</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','711628');" title="광(狂) 재생 - 새창">광(狂)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','905857');" title="세글자 (드라마 '루루공주' 김정은 메인 테마) 재생 - 새창">세글자 (드라마 '루루공주' 김정은 메인 테마)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','866705');" title="제자리 걸음 재생 - 새창">제자리 걸음</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','732519');" title="가시 재생 - 새창">가시</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','845586');" title="I Love U Oh Thank U (Feat. 김태우 Of God) 재생 - 새창">I Love U Oh Thank U (Feat. 김태우 Of God)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','631232');" title="둘이서 (CF - 빙그레 '바나나맛 우유') 재생 - 새창">둘이서 (CF - 빙그레 '바나나맛 우유')</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','864916');" title="너에게 전하는 아홉가지 바램 재생 - 새창">너에게 전하는 아홉가지 바램</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','864906');" title="Smile Again 재생 - 새창">Smile Again</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','698972');" title="사랑은...하나다 재생 - 새창">사랑은...하나다</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','847132');" title="체념 後(후) 재생 - 새창">체념 後(후)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','665226');" title="귀로 재생 - 새창">귀로</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','898497');" title="내 눈물이 하는 말 재생 - 새창">내 눈물이 하는 말</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','933372');" title="Fly (Feat. Amin. J of Soulciety) 재생 - 새창">Fly (Feat. Amin. J of Soulciety)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','732373');" title="사랑인걸 재생 - 새창">사랑인걸</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','866710');" title="사랑스러워 재생 - 새창">사랑스러워</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','732516');" title="나에게로 떠나는 여행 재생 - 새창">나에게로 떠나는 여행</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','866714');" title="별, 바람, 햇살 그리고 사랑 재생 - 새창">별, 바람, 햇살 그리고 사랑</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','672010');" title="꽃피는 봄이오면 재생 - 새창">꽃피는 봄이오면</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','742311');" title="안부 (Duet With 나윤권) 재생 - 새창">안부 (Duet With 나윤권)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','905582');" title="아니 재생 - 새창">아니</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','928697');" title="일년이면 재생 - 새창">일년이면</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','531840');" title="Y (Please Tell Me Why) 재생 - 새창">Y (Please Tell Me Why)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','848156');" title="가슴 아파도 재생 - 새창">가슴 아파도</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','845580');" title="천하무적 (Feat. 박장근 Of Supersta) 재생 - 새창">천하무적 (Feat. 박장근 Of Supersta)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','733379');" title="Super Star 재생 - 새창">Super Star</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','884783');" title="한숨만 재생 - 새창">한숨만</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','891878');" title="으라차차 재생 - 새창">으라차차</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','623250');" title="보통날 재생 - 새창">보통날</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','971439');" title="내가 웃는게 아니야 (Feat. ALI) 재생 - 새창">내가 웃는게 아니야 (Feat. ALI)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','708213');" title="눈물이 나요 재생 - 새창">눈물이 나요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','891991');" title="환희 재생 - 새창">환희</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','926191');" title="내 마음의 보석상자 재생 - 새창">내 마음의 보석상자</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','866706');" title="그녀의 남자에게 재생 - 새창">그녀의 남자에게</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','732513');" title="벌 재생 - 새창">벌</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','842022');" title="같은 생각 재생 - 새창">같은 생각</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','864433');" title="Girls On Top 재생 - 새창">Girls On Top</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','903404');" title="지지 않는 태양 (Feat. 한 에스더) 재생 - 새창">지지 않는 태양 (Feat. 한 에스더)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','686651');" title="응급실 재생 - 새창">응급실</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','847126');" title="여자 재생 - 새창">여자</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','985472');" title="Happiness 재생 - 새창">Happiness</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','827216');" title="잘 지내나요 재생 - 새창">잘 지내나요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','732515');" title="거짓말 재생 - 새창">거짓말</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','667278');" title="봄날 재생 - 새창">봄날</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','851277');" title="떠나가요, 떠나지마요 재생 - 새창">떠나가요, 떠나지마요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','1008495');" title="사랑은 가슴이 시킨다 재생 - 새창">사랑은 가슴이 시킨다</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','622912');" title="헤어지자고 (MBC 슬픈연가 삽입곡) 재생 - 새창">헤어지자고 (MBC 슬픈연가 삽입곡)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','623902');" title="눈의 꽃 재생 - 새창">눈의 꽃</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','642420');" title="겨울일기 재생 - 새창">겨울일기</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','985785');" title="Anyclub (Feat.Teddy) ( CF - Anycall Anyclub 이효리, 에릭, 권상우편 ) 재생 - 새창">Anyclub (Feat.Teddy) ( CF - Anycall Anyclub 이효리, 에릭, 권상우편 )</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','845591');" title="홈런 (Feat. 옥주현) 재생 - 새창">홈런 (Feat. 옥주현)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','775130');" title="여기까진가요 재생 - 새창">여기까진가요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','698979');" title="그리움을 사랑한 가시나무 재생 - 새창">그리움을 사랑한 가시나무</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','888345');" title="추억속의 재회 재생 - 새창">추억속의 재회</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','904628');" title="1,2,3,4. (원,투,쓰리,포.) 재생 - 새창">1,2,3,4. (원,투,쓰리,포.)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','864907');" title="은영이에게 Part 2 재생 - 새창">은영이에게 Part 2</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','711630');" title="입술만 깨물고있죠 재생 - 새창">입술만 깨물고있죠</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','933390');" title="그리고 그후 재생 - 새창">그리고 그후</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','860577');" title="보통여자 재생 - 새창">보통여자</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','623251');" title="약속(Narration 강경헌) 재생 - 새창">약속(Narration 강경헌)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','833665');" title="중독 재생 - 새창">중독</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','686637');" title="Memory 재생 - 새창">Memory</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','851423');" title="흩어진 나날들 재생 - 새창">흩어진 나날들</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','602014');" title="불치병 (Feat. Masta Wu) 재생 - 새창">불치병 (Feat. Masta Wu)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','894063');" title="눈물씻고 화장하고 재생 - 새창">눈물씻고 화장하고</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','708211');" title="Mr. Flower 재생 - 새창">Mr. Flower</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','848804');" title="나비무덤 재생 - 새창">나비무덤</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','711629');" title="가 재생 - 새창">가</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','864431');" title="Moto 재생 - 새창">Moto</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','537749');" title="날 그만 잊어요 재생 - 새창">날 그만 잊어요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','993956');" title="Bye Bye Bye 재생 - 새창">Bye Bye Bye</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','622649');" title="전화번호 재생 - 새창">전화번호</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','882495');" title="이여름  Summer 재생 - 새창">이여름  Summer</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','986817');" title="2♡ 재생 - 새창">2♡</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','843729');" title="그녀에게 재생 - 새창">그녀에게</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','632780');" title="세월의 흔적 다 버리고 재생 - 새창">세월의 흔적 다 버리고</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','667794');" title="꽃들은 지고 재생 - 새창">꽃들은 지고</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','732514');" title="1st 재생 - 새창">1st</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','976103');" title="Stay in Me 재생 - 새창">Stay in Me</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','623157');" title="빙고 재생 - 새창">빙고</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','905587');" title="혼자만 하는 사랑 재생 - 새창">혼자만 하는 사랑</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','926193');" title="꿈의 대화 (R&amp;B Soul ver.) 재생 - 새창">꿈의 대화 (R&amp;B Soul ver.)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','985474');" title="그래도 살아가겠지 재생 - 새창">그래도 살아가겠지</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','916286');" title="Rising Sun (순수) 재생 - 새창">Rising Sun (순수)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','775161');" title="눈물잔 재생 - 새창">눈물잔</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','863192');" title="Hi Ya Ya 여름날 재생 - 새창">Hi Ya Ya 여름날</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33260173');" title="닮았잖아 재생 - 새창">닮았잖아</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','1009239');" title="사랑은 아프려고 하는 거죠 재생 - 새창">사랑은 아프려고 하는 거죠</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','634613');" title="Tonight 재생 - 새창">Tonight</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','665221');" title="언젠가는 재생 - 새창">언젠가는</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','537210');" title="은영이에게 재생 - 새창">은영이에게</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','979391');" title="잘 부탁드립니다 (CF - 한국야쿠르트 산타페 EX편) 재생 - 새창">잘 부탁드립니다 (CF - 한국야쿠르트 산타페 EX편)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','622664');" title="빙고 (아싸) 재생 - 새창">빙고 (아싸)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','931730');" title="2 A.M (2:00am) 재생 - 새창">2 A.M (2:00am)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','931286');" title="현명한 이별 재생 - 새창">현명한 이별</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','978136');" title="기대 재생 - 새창">기대</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','855659');" title="She Is 재생 - 새창">She Is</a></strong>
#  </span></div>]

# %%
[title.find('a').get_text() for title in soup.find_all('div', attrs={'class': 'ellipsis rank01'})]
# Out:
# ['죄와벌',
#  '겁쟁이',
#  '사랑했나봐',
#  '살다가',
#  '광(狂)',
#  "세글자 (드라마 '루루공주' 김정은 메인 테마)",
#  '제자리 걸음',
#  '가시',
#  'I Love U Oh Thank U (Feat. 김태우 Of God)',
#  "둘이서 (CF - 빙그레 '바나나맛 우유')",
#  '너에게 전하는 아홉가지 바램',
#  'Smile Again',
#  '사랑은...하나다',
#  '체념 後(후)',
#  '귀로',
#  '내 눈물이 하는 말',
#  'Fly (Feat. Amin. J of Soulciety)',
#  '사랑인걸',
#  '사랑스러워',
#  '나에게로 떠나는 여행',
#  '별, 바람, 햇살 그리고 사랑',
#  '꽃피는 봄이오면',
#  '안부 (Duet With 나윤권)',
#  '아니',
#  '일년이면',
#  'Y (Please Tell Me Why)',
#  '가슴 아파도',
#  '천하무적 (Feat. 박장근 Of Supersta)',
#  'Super Star',
#  '한숨만',
#  '으라차차',
#  '보통날',
#  '내가 웃는게 아니야 (Feat. ALI)',
#  '눈물이 나요',
#  '환희',
#  '내 마음의 보석상자',
#  '그녀의 남자에게',
#  '벌',
#  '같은 생각',
#  'Girls On Top',
#  '지지 않는 태양 (Feat. 한 에스더)',
#  '응급실',
#  '여자',
#  'Happiness',
#  '잘 지내나요',
#  '거짓말',
#  '봄날',
#  '떠나가요, 떠나지마요',
#  '사랑은 가슴이 시킨다',
#  '헤어지자고 (MBC 슬픈연가 삽입곡)',
#  '눈의 꽃',
#  '겨울일기',
#  'Anyclub (Feat.Teddy) ( CF - Anycall Anyclub 이효리, 에릭, 권상우편 )',
#  '홈런 (Feat. 옥주현)',
#  '여기까진가요',
#  '그리움을 사랑한 가시나무',
#  '추억속의 재회',
#  '1,2,3,4. (원,투,쓰리,포.)',
#  '은영이에게 Part 2',
#  '입술만 깨물고있죠',
#  '그리고 그후',
#  '보통여자',
#  '약속(Narration 강경헌)',
#  '중독',
#  'Memory',
#  '흩어진 나날들',
#  '불치병 (Feat. Masta Wu)',
#  '눈물씻고 화장하고',
#  'Mr. Flower',
#  '나비무덤',
#  '가',
#  'Moto',
#  '날 그만 잊어요',
#  'Bye Bye Bye',
#  '전화번호',
#  '이여름  Summer',
#  '2♡',
#  '그녀에게',
#  '세월의 흔적 다 버리고',
#  '꽃들은 지고',
#  '1st',
#  'Stay in Me',
#  '빙고',
#  '혼자만 하는 사랑',
#  '꿈의 대화 (R&B Soul ver.)',
#  '그래도 살아가겠지',
#  'Rising Sun (순수)',
#  '눈물잔',
#  'Hi Ya Ya 여름날',
#  '닮았잖아',
#  '사랑은 아프려고 하는 거죠',
#  'Tonight',
#  '언젠가는',
#  '은영이에게',
#  '잘 부탁드립니다 (CF - 한국야쿠르트 산타페 EX편)',
#  '빙고 (아싸)',
#  '2 A.M (2:00am)',
#  '현명한 이별',
#  '기대',
#  'She Is']

# %% [markdown]
# # Artist Name

# %%
soup.find_all('span', attrs={'class':'checkEllipsis'})
# Out:
# [<span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('923');" title="윤도현 - 페이지 이동">윤도현</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108581');" title="엠투엠 (M To M) - 페이지 이동">엠투엠 (M To M)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1692');" title="김종국 - 페이지 이동">김종국</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('11538');" title="MC몽 - 페이지 이동">MC몽</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('41894');" title="채연 - 페이지 이동">채연</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('45995');" title="KCM - 페이지 이동">KCM</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('45995');" title="KCM - 페이지 이동">KCM</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('51893');" title="테이 - 페이지 이동">테이</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('105803');" title="빅마마 - 페이지 이동">빅마마</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('3959');" title="나얼 - 페이지 이동">나얼</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('172281');" title="견우 (Kyunwoo) - 페이지 이동">견우 (Kyunwoo)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108356');" title="에픽하이 (EPIK HIGH) - 페이지 이동">에픽하이 (EPIK HIGH)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('165535');" title="모세 - 페이지 이동">모세</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1692');" title="김종국 - 페이지 이동">김종국</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1692');" title="김종국 - 페이지 이동">김종국</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('36142');" title="BMK - 페이지 이동">BMK</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('27033');" title="별 - 페이지 이동">별</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('30358');" title="거미 - 페이지 이동">거미</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('10577');" title="휘성 (Realslow) - 페이지 이동">휘성 (Realslow)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100144');" title="프리스타일 - 페이지 이동">프리스타일</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1928');" title="환희 - 페이지 이동">환희</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('11538');" title="MC몽 - 페이지 이동">MC몽</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('101487');" title="쥬얼리 - 페이지 이동">쥬얼리</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('39256');" title="이정(J.Lee) - 페이지 이동">이정(J.Lee)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108951');" title="럼블피쉬 - 페이지 이동">럼블피쉬</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100007');" title="god - 페이지 이동">god</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('103289');" title="리쌍 - 페이지 이동">리쌍</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('969');" title="조성모 - 페이지 이동">조성모</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('3865');" title="싸이 (PSY) - 페이지 이동">싸이 (PSY)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1692');" title="김종국 - 페이지 이동">김종국</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1741');" title="신혜성 - 페이지 이동">신혜성</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2165');" title="보아 (BoA) - 페이지 이동">보아 (BoA)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1585');" title="장우혁 - 페이지 이동">장우혁</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('164914');" title="izi - 페이지 이동">izi</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('105803');" title="빅마마 - 페이지 이동">빅마마</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('174997');" title="가비엔제이 - 페이지 이동">가비엔제이</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('3305');" title="성시경 - 페이지 이동">성시경</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('35155');" title="아이 - 페이지 이동">아이</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('107224');" title="더 크로스 - 페이지 이동">더 크로스</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('14801');" title="윤건 - 페이지 이동">윤건</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1191');" title="박효신 - 페이지 이동">박효신</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('10575');" title="장나라 - 페이지 이동">장나라</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1713');" title="이효리 - 페이지 이동">이효리</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('11538');" title="MC몽 - 페이지 이동">MC몽</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100391');" title="플라워 - 페이지 이동">플라워</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('51893');" title="테이 - 페이지 이동">테이</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('161636');" title="엠씨더맥스 (M.C the MAX) - 페이지 이동">엠씨더맥스 (M.C the MAX)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100022');" title="코요태 - 페이지 이동">코요태</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('45995');" title="KCM - 페이지 이동">KCM</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100144');" title="프리스타일 - 페이지 이동">프리스타일</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('8530');" title="린 - 페이지 이동">린</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100007');" title="god - 페이지 이동">god</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('3033');" title="서영은 - 페이지 이동">서영은</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('6502');" title="김범수 - 페이지 이동">김범수</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1191');" title="박효신 - 페이지 이동">박효신</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('10577');" title="휘성 (Realslow) - 페이지 이동">휘성 (Realslow)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('7664');" title="렉시 - 페이지 이동">렉시</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('969');" title="조성모 - 페이지 이동">조성모</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('105789');" title="테이크 (TAKE) - 페이지 이동">테이크 (TAKE)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2165');" title="보아 (BoA) - 페이지 이동">보아 (BoA)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('30358');" title="거미 - 페이지 이동">거미</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('175155');" title="먼데이 키즈 (Monday Kiz) - 페이지 이동">먼데이 키즈 (Monday Kiz)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100054');" title="지누션 - 페이지 이동">지누션</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100004');" title="쿨 (COOL) - 페이지 이동">쿨 (COOL)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100007');" title="god - 페이지 이동">god</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100737');" title="유엔 - 페이지 이동">유엔</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100078');" title="신화 - 페이지 이동">신화</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('995');" title="이수영 - 페이지 이동">이수영</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('160091');" title="버즈 - 페이지 이동">버즈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1819');" title="서지영 - 페이지 이동">서지영</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('100022');" title="코요태 - 페이지 이동">코요태</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('30358');" title="거미 - 페이지 이동">거미</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('174997');" title="가비엔제이 - 페이지 이동">가비엔제이</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108316');" title="동방신기 (TVXQ!) - 페이지 이동">동방신기 (TVXQ!)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('956');" title="박상민 - 페이지 이동">박상민</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108316');" title="동방신기 (TVXQ!) - 페이지 이동">동방신기 (TVXQ!)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('984');" title="이소은 - 페이지 이동">이소은</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('161636');" title="엠씨더맥스 (M.C the MAX) - 페이지 이동">엠씨더맥스 (M.C the MAX)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('891');" title="홍경민 - 페이지 이동">홍경민</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('3959');" title="나얼 - 페이지 이동">나얼</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('45995');" title="KCM - 페이지 이동">KCM</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('174838');" title="익스 - 페이지 이동">익스</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('101463');" title="거북이 - 페이지 이동">거북이</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('174009');" title="전혜빈 - 페이지 이동">전혜빈</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('101447');" title="슈가 - 페이지 이동">슈가</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('58979');" title="나윤권 - 페이지 이동">나윤권</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('107725');" title="클래지콰이 - 페이지 이동">클래지콰이</a></span>]

# %%
[singer.get_text() for singer in soup.find_all('span', attrs={'class':'checkEllipsis'})]
# Out:
# ['SG 워너비',
#  '버즈',
#  '윤도현',
#  'SG 워너비',
#  'SG 워너비',
#  '엠투엠 (M To M)',
#  '김종국',
#  '버즈',
#  'MC몽',
#  '채연',
#  'KCM',
#  'KCM',
#  '테이',
#  '빅마마',
#  '나얼',
#  '견우 (Kyunwoo)',
#  '에픽하이 (EPIK HIGH)',
#  '모세',
#  '김종국',
#  '버즈',
#  '김종국',
#  'BMK',
#  '별',
#  '거미',
#  '휘성 (Realslow)',
#  '프리스타일',
#  '환희',
#  'MC몽',
#  '쥬얼리',
#  '이정(J.Lee)',
#  '럼블피쉬',
#  'god',
#  '리쌍',
#  '조성모',
#  '싸이 (PSY)',
#  'SG 워너비',
#  '김종국',
#  '버즈',
#  '신혜성',
#  '보아 (BoA)',
#  '장우혁',
#  'izi',
#  '빅마마',
#  '가비엔제이',
#  '성시경',
#  '버즈',
#  '아이',
#  '더 크로스',
#  '버즈',
#  '윤건',
#  '박효신',
#  '장나라',
#  '이효리',
#  'MC몽',
#  '플라워',
#  '테이',
#  '엠씨더맥스 (M.C the MAX)',
#  '코요태',
#  'KCM',
#  'SG 워너비',
#  '프리스타일',
#  '린',
#  'god',
#  '서영은',
#  '김범수',
#  '박효신',
#  '휘성 (Realslow)',
#  '렉시',
#  '조성모',
#  '테이크 (TAKE)',
#  'SG 워너비',
#  '보아 (BoA)',
#  '거미',
#  '먼데이 키즈 (Monday Kiz)',
#  '지누션',
#  '쿨 (COOL)',
#  'god',
#  '유엔',
#  '신화',
#  '이수영',
#  '버즈',
#  '서지영',
#  '코요태',
#  '거미',
#  'SG 워너비',
#  '가비엔제이',
#  '동방신기 (TVXQ!)',
#  '박상민',
#  '동방신기 (TVXQ!)',
#  '이소은',
#  '엠씨더맥스 (M.C the MAX)',
#  '홍경민',
#  '나얼',
#  'KCM',
#  '익스',
#  '거북이',
#  '전혜빈',
#  '슈가',
#  '나윤권',
#  '클래지콰이']

# %% [markdown]
# # Rank

# %%
song = [title.find('a').get_text() for title in soup.find_all('div', attrs = {'class': 'ellipsis rank01'})]
rank = []
for i in range(len(song)):
    rank.append(i+1)

# %% [markdown]
# # year

# %%
soup.find_all('span', attrs={'class':'datelk'})
# Out:
# [<span class="datelk">2005</span>]

# %%
soup.find_all('span', attrs={'class':'datelk'})[0].get_text()
# Out:
# '2005'

# %% [markdown]
# # Function

# %%
result_df = pd.DataFrame()


#open Chromedriver

driver = wd.Chrome('/chromedriver') #path
driver.maximize_window() #maximise the size of chrome window

#access to specific URL
url = 'https://www.melon.com/chart/index.htm'
driver.get(url)
# Out:
# /var/folders/hq/nqwncw9n70j0_vwz8bkfhkf80000gn/T/ipykernel_68502/3270001822.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('/chromedriver') #path

# %%
def scraping(Decade, Year):

    result_df = pd.DataFrame()

    #select chart_finder

    driver.find_element(By.XPATH, '//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()

    # Yearly Chart
    driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/h4[3]/a').click()
    time.sleep(2)

    # Select Decade (2000s)
    driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[{Decade}]/span/label').click()
    time.sleep(2)

    # Select Year (2005 - (li[10]), 2009 - (li[1]))
    driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[{Year}]/span/label').click()
    time.sleep(2)

    # Select Domestic Chart
    driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[2]/span/label').click()
    time.sleep(2)


    #Click 'Search'
    driver.find_element(By.XPATH, '//*[@id="d_srch_form"]/div[2]/button/span/span').click()


    #html
    html = driver.page_source #cf) requests.get(url)
    soup = BeautifulSoup(html, 'lxml')

    title_lst = [title.find('a').get_text() for title in soup.find_all('div', attrs={'class': 'ellipsis rank01'})]
    artist_lst = [singer.get_text() for singer in soup.find_all('span', attrs={'class':'checkEllipsis'})]

    rank_lst = []
    for i in range(len(title_lst)):
        rank.append(i+1)
    
    year = soup.find_all('span', attrs={'class':'datelk'})[0].get_text()
    year_lst = list(repeat(soup.find_all('span', attrs={'class':'datelk'})[0].get_text(), len(title_lst)))
    
    
    df = pd.DataFrame({'YEAR':year_lst,'RANK':rank_lst,'TITLE':title_lst,'ARTIST':artist_lst})
    result_df = pd.concat([result_df, df], ignore_index=True)

# %%
#Decade | Year
# 2020 - 1 | 2 - 1
# 2010 - 2 | 10 - 1
# 2000 - 3 | 5 - 1

# %%
scraping(3,5)

# %%
result_df.to_csv('멜론차트크롤링.csv', encoding='ANSI')
