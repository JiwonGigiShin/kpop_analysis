# %% [markdown]
# # Module

# %%
import selenium
from selenium import webdriver as wd
import time
import pandas as pd
from bs4 import BeautifulSoup
import requests
from itertools import repeat
from selenium.webdriver.common.by import By

# %% [markdown]
# # Chrome Driver

# %%
#open Chromedriver

driver = wd.Chrome('../crawling/chromedriver') #path
driver.maximize_window() #maximise the size of chrome window

#access to specific URL
url = 'https://www.melon.com/chart/index.htm'
driver.get(url)
# Out:
# /var/folders/hq/nqwncw9n70j0_vwz8bkfhkf80000gn/T/ipykernel_48631/1820330060.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('../crawling/chromedriver') #path

# %% [markdown]
# # Filter

# %%
#select chart finder
driver.find_element(By.XPATH, '//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()

# %%
# DECADE, YEAR, MONTH, GENRE

# Yearly Chart
driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/h4[3]/a').click()
time.sleep(2)

# %%
# Select Decade (2020s)

driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[1]/span').click()
time.sleep(2)

# %%
# Select Year (2005~2009) 
# 2000 = li[10],... 2009 = li[1]
driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[1]/span').click()
time.sleep(2)

# %%
# Select 'Domestic Chart'

driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[2]/span').click()
time.sleep(2)

# %%
# Click 'Search'

driver.find_element(By.XPATH, '//*[@id="d_srch_form"]/div[2]/button/span').click()

# %% [markdown]
# # html

# %%
# ! pip install lxml

# %%
html = driver.page_source #cf) requests.get(url)
soup = BeautifulSoup(html, 'lxml')

# %% [markdown]
# # Song title

# %%
soup.find_all('div', attrs = {'class': 'ellipsis rank01'})
# Out:
# [<div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33239419');" title="Celebrity 재생 - 새창">Celebrity</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','30287019');" title="롤린 (Rollin') 재생 - 새창">롤린 (Rollin')</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32872978');" title="Dynamite 재생 - 새창">Dynamite</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33487342');" title="Next Level 재생 - 새창">Next Level</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33372781');" title="라일락 재생 - 새창">라일락</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33061995');" title="밤하늘의 별을(2020) 재생 - 새창">밤하늘의 별을(2020)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33480898');" title="신호등 재생 - 새창">신호등</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33507137');" title="Butter 재생 - 새창">Butter</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','3414749');" title="내 손을 잡아 재생 - 새창">내 손을 잡아</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33167063');" title="밝게 빛나는 별이 되어 비춰줄게 재생 - 새창">밝게 빛나는 별이 되어 비춰줄게</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33625988');" title="바라만 본다 재생 - 새창">바라만 본다</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33013877');" title="잠이 오질 않네요 재생 - 새창">잠이 오질 않네요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33503722');" title="헤픈 우연 재생 - 새창">헤픈 우연</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32961718');" title="Lovesick Girls 재생 - 새창">Lovesick Girls</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32794652');" title="취기를 빌려 (취향저격 그녀 X 산들) 재생 - 새창">취기를 빌려 (취향저격 그녀 X 산들)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33077590');" title="VVS (Feat. JUSTHIS) (Prod. GroovyRoom) 재생 - 새창">VVS (Feat. JUSTHIS) (Prod. GroovyRoom)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32860397');" title="운전만해 (We Ride) 재생 - 새창">운전만해 (We Ride)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33464805');" title="Dun Dun Dance 재생 - 새창">Dun Dun Dance</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32183386');" title="Blueming 재생 - 새창">Blueming</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32578498');" title="에잇(Prod.&amp;Feat. SUGA of BTS) 재생 - 새창">에잇(Prod.&amp;Feat. SUGA of BTS)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32061975');" title="어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 재생 - 새창">어떻게 이별까지 사랑하겠어, 널 사랑하는 거지</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','3894276');" title="오래된 노래 재생 - 새창">오래된 노래</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32003395');" title="흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 재생 - 새창">흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33107649');" title="그날에 나는 맘이 편했을까 재생 - 새창">그날에 나는 맘이 편했을까</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33077234');" title="Life Goes On 재생 - 새창">Life Goes On</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','30962526');" title="모든 날, 모든 순간 (Every day, Every Moment) 재생 - 새창">모든 날, 모든 순간 (Every day, Every Moment)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33331004');" title="LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지) 재생 - 새창">LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33011180');" title="나랑 같이 걸을래 (바른연애 길잡이 X 적재) 재생 - 새창">나랑 같이 걸을래 (바른연애 길잡이 X 적재)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','31737197');" title="작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) 재생 - 새창">작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33397561');" title="ASAP 재생 - 새창">ASAP</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32224272');" title="METEOR 재생 - 새창">METEOR</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','1944399');" title="Timeless 재생 - 새창">Timeless</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33359725');" title="사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco) 재생 - 새창">사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32491274');" title="아로하 재생 - 새창">아로하</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33655994');" title="Weekend 재생 - 새창">Weekend</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32559782');" title="Dolphin 재생 - 새창">Dolphin</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','30244931');" title="봄날 재생 - 새창">봄날</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33666269');" title="Permission to Dance 재생 - 새창">Permission to Dance</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33315511');" title="멜로디 재생 - 새창">멜로디</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33248758');" title="추억은 만남보다 이별에 남아 재생 - 새창">추억은 만남보다 이별에 남아</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32698101');" title="OHAYO MY NIGHT 재생 - 새창">OHAYO MY NIGHT</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','31853557');" title="오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) 재생 - 새창">오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33725775');" title="낙하 (with 아이유) 재생 - 새창">낙하 (with 아이유)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32508053');" title="이제 나만 믿어요 재생 - 새창">이제 나만 믿어요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32525311');" title="사실 나는 (Feat.전건호) 재생 - 새창">사실 나는 (Feat.전건호)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33496587');" title="다정히 내 이름을 부르면 재생 - 새창">다정히 내 이름을 부르면</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33346446');" title="On The Ground 재생 - 새창">On The Ground</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32998018');" title="힘든 건 사랑이 아니다 재생 - 새창">힘든 건 사랑이 아니다</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32438894');" title="어떻게 지내 (Prod. By VAN.C) 재생 - 새창">어떻게 지내 (Prod. By VAN.C)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33229299');" title="이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM) 재생 - 새창">이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32224166');" title="너의 번호를 누르고 (Prod. 영화처럼) 재생 - 새창">너의 번호를 누르고 (Prod. 영화처럼)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33372783');" title="Coin 재생 - 새창">Coin</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32156286');" title="늦은 밤 너의 집 앞 골목길에서 재생 - 새창">늦은 밤 너의 집 앞 골목길에서</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33372788');" title="어푸 (Ah puh) 재생 - 새창">어푸 (Ah puh)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32720013');" title="How You Like That 재생 - 새창">How You Like That</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','8130796');" title="상상더하기 재생 - 새창">상상더하기</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33589488');" title="비와 당신 재생 - 새창">비와 당신</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','1854856');" title="라라라 재생 - 새창">라라라</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32378104');" title="마음을 드려요 재생 - 새창">마음을 드려요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32559781');" title="살짝 설렜어 (Nonstop) 재생 - 새창">살짝 설렜어 (Nonstop)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33691794');" title="좋아좋아 재생 - 새창">좋아좋아</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32871975');" title="내 마음이 움찔했던 순간 (취향저격 그녀 X 규현) 재생 - 새창">내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33589260');" title="치맛바람 (Chi Mat Ba Ram) 재생 - 새창">치맛바람 (Chi Mat Ba Ram)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33527705');" title="안녕 (Hello) 재생 - 새창">안녕 (Hello)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33559180');" title="Alcohol-Free 재생 - 새창">Alcohol-Free</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33115807');" title="내일이 오면 (Feat. 기리보이, BIG Naughty (서동현)) 재생 - 새창">내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32143487');" title="Love poem 재생 - 새창">Love poem</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','31388145');" title="너를 만나 재생 - 새창">너를 만나</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','1500196');" title="내사람 재생 - 새창">내사람</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32853712');" title="When We Disco (Duet with 선미) 재생 - 새창">When We Disco (Duet with 선미)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33510307');" title="상상더하기 재생 - 새창">상상더하기</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32345931');" title="시작 재생 - 새창">시작</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32187544');" title="우리 왜 헤어져야 해 재생 - 새창">우리 왜 헤어져야 해</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33618271');" title="하루만 더 재생 - 새창">하루만 더</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33104090');" title="혼술하고 싶은 밤 재생 - 새창">혼술하고 싶은 밤</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33625989');" title="나를 아는 사람 재생 - 새창">나를 아는 사람</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','31984204');" title="안녕 재생 - 새창">안녕</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33749109');" title="DUMB DUMB 재생 - 새창">DUMB DUMB</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32570501');" title="서면역에서 재생 - 새창">서면역에서</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32777869');" title="거짓말이라도 해서 널 보고싶어 재생 - 새창">거짓말이라도 해서 널 보고싶어</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33260801');" title="고백 (바른연애 길잡이 X 허각) 재생 - 새창">고백 (바른연애 길잡이 X 허각)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33164083');" title="우린 어쩌다 헤어진 걸까 재생 - 새창">우린 어쩌다 헤어진 걸까</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','30773554');" title="Downtown Baby 재생 - 새창">Downtown Baby</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','34101563');" title="strawberry moon 재생 - 새창">strawberry moon</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','34041584');" title="Savage 재생 - 새창">Savage</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33447280');" title="마.피.아. In the morning 재생 - 새창">마.피.아. In the morning</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33805289');" title="Queendom 재생 - 새창">Queendom</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33405149');" title="그냥 안아달란 말야 재생 - 새창">그냥 안아달란 말야</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33372787');" title="아이와 나의 바다 재생 - 새창">아이와 나의 바다</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33618864');" title="가을 우체국 앞에서 재생 - 새창">가을 우체국 앞에서</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','34256568');" title="회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom) 재생 - 새창">회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32651098');" title="사랑은 지날수록 더욱 선명하게 남아 재생 - 새창">사랑은 지날수록 더욱 선명하게 남아</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33347390');" title="이렇게 좋아해 본 적이 없어요 재생 - 새창">이렇게 좋아해 본 적이 없어요</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','32725013');" title="마리아 (Maria) 재생 - 새창">마리아 (Maria)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33001672');" title="딩가딩가 (Dingga) 재생 - 새창">딩가딩가 (Dingga)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33295747');" title="함께 했는데 이별은 나 혼자인 거야 재생 - 새창">함께 했는데 이별은 나 혼자인 거야</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33759183');" title="비가 오는 날엔 (2021) 재생 - 새창">비가 오는 날엔 (2021)</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','711626');" title="살다가 재생 - 새창">살다가</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33337651');" title="별빛 같은 나의 사랑아 재생 - 새창">별빛 같은 나의 사랑아</a></strong>
#  </span></div>,
#  <div class="ellipsis rank01"><span>
#  <strong><a href="javascript:melon.play.playSong('19080101','33150997');" title="CREDIT (Feat. 염따, 기리보이, Zion.T) 재생 - 새창">CREDIT (Feat. 염따, 기리보이, Zion.T)</a></strong>
#  </span></div>]

# %%
[title.find('a').get_text() for title in soup.find_all('div', attrs={'class': 'ellipsis rank01'})]
# Out:
# ['Celebrity',
#  "롤린 (Rollin')",
#  'Dynamite',
#  'Next Level',
#  '라일락',
#  '밤하늘의 별을(2020)',
#  '신호등',
#  'Butter',
#  '내 손을 잡아',
#  '밝게 빛나는 별이 되어 비춰줄게',
#  '바라만 본다',
#  '잠이 오질 않네요',
#  '헤픈 우연',
#  'Lovesick Girls',
#  '취기를 빌려 (취향저격 그녀 X 산들)',
#  'VVS (Feat. JUSTHIS) (Prod. GroovyRoom)',
#  '운전만해 (We Ride)',
#  'Dun Dun Dance',
#  'Blueming',
#  '에잇(Prod.&Feat. SUGA of BTS)',
#  '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#  '오래된 노래',
#  '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#  '그날에 나는 맘이 편했을까',
#  'Life Goes On',
#  '모든 날, 모든 순간 (Every day, Every Moment)',
#  'LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)',
#  '나랑 같이 걸을래 (바른연애 길잡이 X 적재)',
#  '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)',
#  'ASAP',
#  'METEOR',
#  'Timeless',
#  '사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)',
#  '아로하',
#  'Weekend',
#  'Dolphin',
#  '봄날',
#  'Permission to Dance',
#  '멜로디',
#  '추억은 만남보다 이별에 남아',
#  'OHAYO MY NIGHT',
#  '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)',
#  '낙하 (with 아이유)',
#  '이제 나만 믿어요',
#  '사실 나는 (Feat.전건호)',
#  '다정히 내 이름을 부르면',
#  'On The Ground',
#  '힘든 건 사랑이 아니다',
#  '어떻게 지내 (Prod. By VAN.C)',
#  '이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)',
#  '너의 번호를 누르고 (Prod. 영화처럼)',
#  'Coin',
#  '늦은 밤 너의 집 앞 골목길에서',
#  '어푸 (Ah puh)',
#  'How You Like That',
#  '상상더하기',
#  '비와 당신',
#  '라라라',
#  '마음을 드려요',
#  '살짝 설렜어 (Nonstop)',
#  '좋아좋아',
#  '내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)',
#  '치맛바람 (Chi Mat Ba Ram)',
#  '안녕 (Hello)',
#  'Alcohol-Free',
#  '내일이 오면 (Feat. 기리보이, BIG Naughty (서동현))',
#  'Love poem',
#  '너를 만나',
#  '내사람',
#  'When We Disco (Duet with 선미)',
#  '상상더하기',
#  '시작',
#  '우리 왜 헤어져야 해',
#  '하루만 더',
#  '혼술하고 싶은 밤',
#  '나를 아는 사람',
#  '안녕',
#  'DUMB DUMB',
#  '서면역에서',
#  '거짓말이라도 해서 널 보고싶어',
#  '고백 (바른연애 길잡이 X 허각)',
#  '우린 어쩌다 헤어진 걸까',
#  'Downtown Baby',
#  'strawberry moon',
#  'Savage',
#  '마.피.아. In the morning',
#  'Queendom',
#  '그냥 안아달란 말야',
#  '아이와 나의 바다',
#  '가을 우체국 앞에서',
#  '회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)',
#  '사랑은 지날수록 더욱 선명하게 남아',
#  '이렇게 좋아해 본 적이 없어요',
#  '마리아 (Maria)',
#  '딩가딩가 (Dingga)',
#  '함께 했는데 이별은 나 혼자인 거야',
#  '비가 오는 날엔 (2021)',
#  '살다가',
#  '별빛 같은 나의 사랑아',
#  'CREDIT (Feat. 염따, 기리보이, Zion.T)']

# %% [markdown]
# # Artist Name

# %%
soup.find_all('span', attrs={'class':'checkEllipsis'})
# Out:
# [<span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('531700');" title="브레이브걸스 - 페이지 이동">브레이브걸스</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2899555');" title="aespa - 페이지 이동">aespa</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('994005');" title="경서 - 페이지 이동">경서</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2138620');" title="이무진 - 페이지 이동">이무진</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2189536');" title="송이한 - 페이지 이동">송이한</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2939212');" title="MSG워너비(M.O.M) - 페이지 이동">MSG워너비(M.O.M)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('648551');" title="장범준 - 페이지 이동">장범준</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('995169');" title="BLACKPINK - 페이지 이동">BLACKPINK</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('672392');" title="산들 - 페이지 이동">산들</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2866523');" title="미란이 (Mirani) - 페이지 이동">미란이 (Mirani)</a>, <a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2747971');" title="먼치맨(MUNCHMAN) - 페이지 이동">먼치맨(MUNCHMAN)</a>, <a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1703507');" title="Khundi Panda - 페이지 이동">Khundi Panda</a>, <a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2745413');" title="머쉬베놈 (MUSHVENOM) - 페이지 이동">머쉬베놈 (MUSHVENOM)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('531700');" title="브레이브걸스 - 페이지 이동">브레이브걸스</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('857994');" title="오마이걸 (OH MY GIRL) - 페이지 이동">오마이걸 (OH MY GIRL)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('712452');" title="AKMU (악뮤) - 페이지 이동">AKMU (악뮤)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('467880');" title="스탠딩 에그 - 페이지 이동">스탠딩 에그</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('648551');" title="장범준 - 페이지 이동">장범준</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('718655');" title="이예준 - 페이지 이동">이예준</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('752425');" title="폴킴 - 페이지 이동">폴킴</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('510565');" title="양요섭 - 페이지 이동">양요섭</a>, <a class="fc_mgray" href="javascript:melon.link.goArtistDetail('644871');" title="정은지 - 페이지 이동">정은지</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('771375');" title="적재 - 페이지 이동">적재</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2899290');" title="STAYC(스테이씨) - 페이지 이동">STAYC(스테이씨)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('774900');" title="창모 (CHANGMO) - 페이지 이동">창모 (CHANGMO)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2754623');" title="호미들 - 페이지 이동">호미들</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('253606');" title="조정석 - 페이지 이동">조정석</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('236797');" title="태연 (TAEYEON) - 페이지 이동">태연 (TAEYEON)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('857994');" title="오마이걸 (OH MY GIRL) - 페이지 이동">오마이걸 (OH MY GIRL)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('672375');" title="방탄소년단 - 페이지 이동">방탄소년단</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2112495');" title="ASH ISLAND - 페이지 이동">ASH ISLAND</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('181188');" title="정동하 - 페이지 이동">정동하</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('785501');" title="디핵 (D-Hack) - 페이지 이동">디핵 (D-Hack)</a>, <a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2750866');" title="PATEKO (파테코) - 페이지 이동">PATEKO (파테코)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('566431');" title="마크툽 (MAKTUB) - 페이지 이동">마크툽 (MAKTUB)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('712452');" title="AKMU (악뮤) - 페이지 이동">AKMU (악뮤)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2863470');" title="경서예지 - 페이지 이동">경서예지</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2863470');" title="경서예지 - 페이지 이동">경서예지</a>, <a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2739011');" title="전건호 - 페이지 이동">전건호</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('995171');" title="로제 (ROSÉ) - 페이지 이동">로제 (ROSÉ)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1142');" title="임창정 - 페이지 이동">임창정</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('925515');" title="오반 - 페이지 이동">오반</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('468244');" title="10CM - 페이지 이동">10CM</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1024489');" title="#안녕 - 페이지 이동">#안녕</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('105623');" title="노을 - 페이지 이동">노을</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('995169');" title="BLACKPINK - 페이지 이동">BLACKPINK</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('783462');" title="라붐 (LABOUM) - 페이지 이동">라붐 (LABOUM)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2138620');" title="이무진 - 페이지 이동">이무진</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('857994');" title="오마이걸 (OH MY GIRL) - 페이지 이동">오마이걸 (OH MY GIRL)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('253606');" title="조정석 - 페이지 이동">조정석</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('205880');" title="규현 (KYUHYUN) - 페이지 이동">규현 (KYUHYUN)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('531700');" title="브레이브걸스 - 페이지 이동">브레이브걸스</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('780922');" title="조이 (JOY) - 페이지 이동">조이 (JOY)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('905701');" title="TWICE (트와이스) - 페이지 이동">TWICE (트와이스)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('623251');" title="릴보이 (lIlBOI) - 페이지 이동">릴보이 (lIlBOI)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('752425');" title="폴킴 - 페이지 이동">폴킴</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1130');" title="박진영 - 페이지 이동">박진영</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2939206');" title="MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 페이지 이동">MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('13494');" title="가호 (Gaho) - 페이지 이동">가호 (Gaho)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2740042');" title="신예영 - 페이지 이동">신예영</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('105803');" title="빅마마 - 페이지 이동">빅마마</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('655051');" title="벤 - 페이지 이동">벤</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2939210');" title="MSG워너비(정상동기) - 페이지 이동">MSG워너비(정상동기)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('752425');" title="폴킴 - 페이지 이동">폴킴</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('968260');" title="전소미 - 페이지 이동">전소미</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2136895');" title="순순희 - 페이지 이동">순순희</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('1118');" title="백지영 - 페이지 이동">백지영</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('28801');" title="허각 - 페이지 이동">허각</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('980594');" title="블루 (BLOO) - 페이지 이동">블루 (BLOO)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2899555');" title="aespa - 페이지 이동">aespa</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2622030');" title="ITZY (있지) - 페이지 이동">ITZY (있지)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('236815');" title="다비치 - 페이지 이동">다비치</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('261143');" title="아이유 - 페이지 이동">아이유</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2086543');" title="김대명 - 페이지 이동">김대명</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('2561475');" title="sokodomo - 페이지 이동">sokodomo</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('979724');" title="전상근 - 페이지 이동">전상근</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('597191');" title="CHEEZE (치즈) - 페이지 이동">CHEEZE (치즈)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('756531');" title="화사 (Hwa Sa) - 페이지 이동">화사 (Hwa Sa)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('750053');" title="마마무 (Mamamoo) - 페이지 이동">마마무 (Mamamoo)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('661792');" title="이소정 - 페이지 이동">이소정</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('108363');" title="SG 워너비 - 페이지 이동">SG 워너비</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('994944');" title="임영웅 - 페이지 이동">임영웅</a></span>,
#  <span class="checkEllipsis" style="display: none;"><a class="fc_mgray" href="javascript:melon.link.goArtistDetail('623251');" title="릴보이 (lIlBOI) - 페이지 이동">릴보이 (lIlBOI)</a></span>]

# %%
[singer.get_text() for singer in soup.find_all('span', attrs={'class':'checkEllipsis'})]
# Out:
# ['아이유',
#  '브레이브걸스',
#  '방탄소년단',
#  'aespa',
#  '아이유',
#  '경서',
#  '이무진',
#  '방탄소년단',
#  '아이유',
#  '송이한',
#  'MSG워너비(M.O.M)',
#  '장범준',
#  '헤이즈 (Heize)',
#  'BLACKPINK',
#  '산들',
#  '미란이 (Mirani), 먼치맨(MUNCHMAN), Khundi Panda, 머쉬베놈 (MUSHVENOM)',
#  '브레이브걸스',
#  '오마이걸 (OH MY GIRL)',
#  '아이유',
#  '아이유',
#  'AKMU (악뮤)',
#  '스탠딩 에그',
#  '장범준',
#  '이예준',
#  '방탄소년단',
#  '폴킴',
#  '양요섭, 정은지',
#  '적재',
#  '방탄소년단',
#  'STAYC(스테이씨)',
#  '창모 (CHANGMO)',
#  'SG 워너비',
#  '호미들',
#  '조정석',
#  '태연 (TAEYEON)',
#  '오마이걸 (OH MY GIRL)',
#  '방탄소년단',
#  '방탄소년단',
#  'ASH ISLAND',
#  '정동하',
#  '디핵 (D-Hack), PATEKO (파테코)',
#  '마크툽 (MAKTUB)',
#  'AKMU (악뮤)',
#  '임영웅',
#  '경서예지',
#  '경서예지, 전건호',
#  '로제 (ROSÉ)',
#  '임창정',
#  '오반',
#  '10CM',
#  '#안녕',
#  '아이유',
#  '노을',
#  '아이유',
#  'BLACKPINK',
#  '라붐 (LABOUM)',
#  '이무진',
#  'SG 워너비',
#  '아이유',
#  '오마이걸 (OH MY GIRL)',
#  '조정석',
#  '규현 (KYUHYUN)',
#  '브레이브걸스',
#  '조이 (JOY)',
#  'TWICE (트와이스)',
#  '릴보이 (lIlBOI)',
#  '아이유',
#  '폴킴',
#  'SG 워너비',
#  '박진영',
#  'MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인)',
#  '가호 (Gaho)',
#  '신예영',
#  '빅마마',
#  '벤',
#  'MSG워너비(정상동기)',
#  '폴킴',
#  '전소미',
#  '순순희',
#  '백지영',
#  '허각',
#  '허각',
#  '블루 (BLOO)',
#  '아이유',
#  'aespa',
#  'ITZY (있지)',
#  'Red Velvet (레드벨벳)',
#  '다비치',
#  '아이유',
#  '김대명',
#  'sokodomo',
#  '전상근',
#  'CHEEZE (치즈)',
#  '화사 (Hwa Sa)',
#  '마마무 (Mamamoo)',
#  '이소정',
#  '헤이즈 (Heize)',
#  'SG 워너비',
#  '임영웅',
#  '릴보이 (lIlBOI)']

# %% [markdown]
# # Rank

# %%
song = [title.find('a').get_text() for title in soup.find_all('div', attrs = {'class': 'ellipsis rank01'})]
rank = []
for i in range(len(song)):
    rank.append(i+1)

# %% [markdown]
# # year

# %%
soup.find_all('span', attrs={'class':'datelk'})
# Out:
# [<span class="datelk">2021</span>]

# %%
soup.find_all('span', attrs={'class':'datelk'})[0].get_text()
# Out:
# '2021'

# %% [markdown]
# # Function

# %%
result_df = pd.DataFrame()

#open Chromedriver
driver = wd.Chrome('../crawling/chromedriver') #path
driver.maximize_window() #maximise the size of chrome window

#access to specific URL
url = 'https://www.melon.com/chart/index.htm'
driver.get(url)
# Out:
# /var/folders/hq/nqwncw9n70j0_vwz8bkfhkf80000gn/T/ipykernel_48631/3270001822.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('/chromedriver') #path

# %%
def scraping(Decade, Year):

    result_df = pd.DataFrame()
    
    #open Chromedriver
    driver = wd.Chrome('../crawling/chromedriver') #path
    driver.maximize_window() #maximise the size of chrome window

    #access to specific URL
    url = 'https://www.melon.com/chart/index.htm'
    driver.get(url)

    #select chart finder
    driver.find_element(By.XPATH, '//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()
    
    # Yearly Chart
    driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/h4[3]/a').click()
    time.sleep(2)

    # Select Decade (2020s)
    driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[{Decade}]/span').click()
#                                     //*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[1]/span
    time.sleep(2)

    # Select Year (2021 - 1)
    driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[{Year}]/span').click()
#                                     //*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[1]/span   
    time.sleep(2)

    # Select Domestic Chart
    driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[2]/span').click()
    time.sleep(2)


    #Click 'Search'
    driver.find_element(By.XPATH, '//*[@id="d_srch_form"]/div[2]/button/span/span').click()


    #html
    html = driver.page_source #cf) requests.get(url)
    soup = BeautifulSoup(html, 'lxml')

    title_lst = [title.find('a').get_text() for title in soup.find_all('div', attrs={'class': 'ellipsis rank01'})]
    artist_lst = [singer.get_text() for singer in soup.find_all('span', attrs={'class':'checkEllipsis'})]

    rank_lst = []
    for i in range(len(title_lst)):
        rank_lst.append(i+1)
    
    year_lst = list(repeat(soup.find_all('span', attrs={'class':'datelk'})[0].get_text(), len(title_lst)))
    
    
    df = pd.DataFrame({'YEAR':year_lst,'RANK':rank_lst,'TITLE':title_lst,'ARTIST':artist_lst})
    result_df = pd.concat([result_df, df], ignore_index=True)
    
    return df

# %%
#Decade | Year
# 2020 - 1 | 2 - 1
# 2010 - 2 | 10 - 1
# 2000 - 3 | 5 - 1

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
scraping(Decade = 1,Year = 1)
print(result_df)
result_df.to_csv('melonchart_2021.csv')
# Out:
# /var/folders/hq/nqwncw9n70j0_vwz8bkfhkf80000gn/T/ipykernel_48631/2746519685.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('../crawling/chromedriver') #path
# Empty DataFrame
# Columns: []
# Index: []

# %%
result_df

# %%
result_df.to_csv('melonchart_2005.csv') #글자 깨질 때 ,encoding='ANSI'

# %%
Decade = 2
Year = 5

result_df = pd.DataFrame()

#open Chromedriver
driver = wd.Chrome('../crawling/chromedriver') #path
driver.maximize_window() #maximise the size of chrome window

#access to specific URL
url = 'https://www.melon.com/chart/index.htm'
driver.get(url)

#select chart finder
driver.find_element(By.XPATH, '//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()

# Yearly Chart
driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/h4[3]/a').click()
time.sleep(2)

# Select Decade (2020s)
driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[{Decade}]/span').click()
#                                     //*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[1]/span
time.sleep(2)

# Select Year (2021 - 1)
driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[{Year}]/span').click()
#                                     //*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[1]/span   
time.sleep(2)

# Select Domestic Chart
driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[2]/span').click()
time.sleep(2)


#Click 'Search'
driver.find_element(By.XPATH, '//*[@id="d_srch_form"]/div[2]/button/span/span').click()


#html
html = driver.page_source #cf) requests.get(url)
soup = BeautifulSoup(html, 'lxml')

title_lst = [title.find('a').get_text() for title in soup.find_all('div', attrs={'class': 'ellipsis rank01'})]
artist_lst = [singer.get_text() for singer in soup.find_all('span', attrs={'class':'checkEllipsis'})]

rank_lst = []
for i in range(len(title_lst)):
    rank_lst.append(i+1)

year_lst = list(repeat(soup.find_all('span', attrs={'class':'datelk'})[0].get_text(), len(title_lst)))


df = pd.DataFrame({'YEAR':year,'RANK':rank,'TITLE':song,'ARTIST':singer})
df
# Out:
# /var/folders/hq/nqwncw9n70j0_vwz8bkfhkf80000gn/T/ipykernel_60049/2411318854.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wd.Chrome('../crawling/chromedriver') #path
#     YEAR  RANK                            TITLE        ARTIST
# 0   2021     1                        Celebrity           아이유
# 1   2021     2                     롤린 (Rollin')        브레이브걸스
# 2   2021     3                         Dynamite         방탄소년단
# 3   2021     4                       Next Level         aespa
# 4   2021     5                              라일락           아이유
# ..   ...   ...                              ...           ...
# 95  2021    96              함께 했는데 이별은 나 혼자인 거야           이소정
# 96  2021    97                  비가 오는 날엔 (2021)   헤이즈 (Heize)
# 97  2021    98                              살다가        SG 워너비
# 98  2021    99                     별빛 같은 나의 사랑아           임영웅
# 99  2021   100  CREDIT (Feat. 염따, 기리보이, Zion.T)  릴보이 (lIlBOI)
#
# [100 rows x 4 columns]

# %% [markdown]
# # Function

# %%
def melon_scrape(Decade, Year):
    
    result_df = pd.DataFrame()

    #open Chromedriver
    driver = wd.Chrome('../crawling/chromedriver') #path
    driver.maximize_window() #maximise the size of chrome window

    #access to specific URL
    url = 'https://www.melon.com/chart/index.htm'
    driver.get(url)

    #select chart finder
    driver.find_element(By.XPATH, '//*[@id="gnb_menu"]/ul[1]/li[1]/div/div/button/span').click()

    # Yearly Chart
    driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/h4[3]/a').click()
    time.sleep(2)

    # Select Decade (2020s)
    driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[{Decade}]/span').click()
    #                                     //*[@id="d_chart_search"]/div/div/div[1]/div[1]/ul/li[1]/span
    time.sleep(2)

    # Select Year (2021 - 1)
    driver.find_element(By.XPATH, f'//*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[{Year}]/span').click()
    #                                     //*[@id="d_chart_search"]/div/div/div[2]/div[1]/ul/li[1]/span   
    time.sleep(2)

    # Select Domestic Chart
    driver.find_element(By.XPATH, '//*[@id="d_chart_search"]/div/div/div[5]/div[1]/ul/li[2]/span').click()
    time.sleep(2)


    #Click 'Search'
    driver.find_element(By.XPATH, '//*[@id="d_srch_form"]/div[2]/button/span/span').click()


    #html
    html = driver.page_source #cf) requests.get(url)
    soup = BeautifulSoup(html, 'lxml')

    title_lst = [title.find('a').get_text() for title in soup.find_all('div', attrs={'class': 'ellipsis rank01'})]
    artist_lst = [singer.get_text() for singer in soup.find_all('span', attrs={'class':'checkEllipsis'})]

    rank_lst = []
    for i in range(len(title_lst)):
        rank_lst.append(i+1)

    year_lst = list(repeat(soup.find_all('span', attrs={'class':'datelk'})[0].get_text(), len(title_lst)))


    df_melon = pd.DataFrame({'YEAR':year,'RANK':rank,'TITLE':song,'ARTIST':singer})
    return df_melon
